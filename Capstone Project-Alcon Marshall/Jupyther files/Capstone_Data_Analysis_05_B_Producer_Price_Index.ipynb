# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv("C:/Users/PC/02_Forward School/Capstone Project-Alcon Marshall/00_Datasets/05 Food Price/producer-prices_mys.csv")

# %%
df
# Out:
#                 Iso3    StartDate     EndDate  Area Code Area Code (M49)  \
# 0      #country+code  #date+start   #date+end        NaN             NaN
# 1                MYS   1991-01-01  1991-12-31      131.0            '458
# 2                MYS   1992-01-01  1992-12-31      131.0            '458
# 3                MYS   1993-01-01  1993-12-31      131.0            '458
# 4                MYS   1994-01-01  1994-12-31      131.0            '458
# ...              ...          ...         ...        ...             ...
# 11595            MYS   2020-01-01  2020-12-31      131.0            '458
# 11596            MYS   2021-01-01  2021-12-31      131.0            '458
# 11597            MYS   2022-01-01  2022-12-31      131.0            '458
# 11598            MYS   2023-01-01  2023-12-31      131.0            '458
# 11599            MYS   2024-01-01  2024-12-31      131.0            '458
#
#                 Area        Item Code Item Code (CPC)  \
# 0      #country+name  #indicator+code             NaN
# 1           Malaysia              226       '01379.01
# 2           Malaysia              226       '01379.01
# 3           Malaysia              226       '01379.01
# 4           Malaysia              226       '01379.01
# ...              ...              ...             ...
# 11595       Malaysia             1800          'F1800
# 11596       Malaysia             1800          'F1800
# 11597       Malaysia             1800          'F1800
# 11598       Malaysia             1800          'F1800
# 11599       Malaysia             1800          'F1800
#
#                            Item  Element Code  \
# 0               #indicator+name           NaN
# 1                    Areca nuts        5539.0
# 2                    Areca nuts        5539.0
# 3                    Areca nuts        5539.0
# 4                    Areca nuts        5539.0
# ...                         ...           ...
# 11595  Vegetables&Melons, Total        5539.0
# 11596  Vegetables&Melons, Total        5539.0
# 11597  Vegetables&Melons, Total        5539.0
# 11598  Vegetables&Melons, Total        5539.0
# 11599  Vegetables&Melons, Total        5539.0
#
#                                       Element  Year Code        Year  \
# 0                                         NaN        NaN  #date+year
# 1      Producer Price Index (2014-2016 = 100)     1991.0        1991
# 2      Producer Price Index (2014-2016 = 100)     1992.0        1992
# 3      Producer Price Index (2014-2016 = 100)     1993.0        1993
# 4      Producer Price Index (2014-2016 = 100)     1994.0        1994
# ...                                       ...        ...         ...
# 11595  Producer Price Index (2014-2016 = 100)     2020.0        2020
# 11596  Producer Price Index (2014-2016 = 100)     2021.0        2021
# 11597  Producer Price Index (2014-2016 = 100)     2022.0        2022
# 11598  Producer Price Index (2014-2016 = 100)     2023.0        2023
# 11599  Producer Price Index (2014-2016 = 100)     2024.0        2024
#
#        Months Code        Months             Unit                 Value Flag
# 0              NaN           NaN  #indicator+type  #indicator+value+num  NaN
# 1           7021.0  Annual value              NaN             43.060000    I
# 2           7021.0  Annual value              NaN             43.300000    I
# 3           7021.0  Annual value              NaN             43.910000    I
# 4           7021.0  Annual value              NaN             44.590000    I
# ...            ...           ...              ...                   ...  ...
# 11595       7021.0  Annual value              NaN            114.070000    I
# 11596       7021.0  Annual value              NaN            127.450000    I
# 11597       7021.0  Annual value              NaN            149.720000    I
# 11598       7021.0  Annual value              NaN            138.680000    I
# 11599       7021.0  Annual value              NaN            144.780000    I
#
# [11600 rows x 18 columns]

# %%
print(df["Item"].unique())
# Out:
# ['#indicator+name' 'Areca nuts' 'Asparagus' 'Bananas' 'Bananas cavendish'
#  'Cabbages' 'Carrots and turnips' 'Cashew nuts, in shell' 'Cassava, fresh'
#  'Cauliflowers and broccoli'
#  'Chillies and peppers, dry (Capsicum spp., Pimenta spp.), raw'
#  'Chillies and peppers, green (Capsicum spp. and Pimenta spp.)'
#  'Cloves (whole stems), raw' 'Cocoa beans' 'Coconuts, in shell'
#  'Coffee, green' 'Cucumbers and gherkins'
#  'Edible roots and tubers with high starch or inulin content, n.e.c., fresh'
#  'Eggplants (aubergines)' 'Eggs from other birds in shell, fresh, n.e.c.'
#  'Ginger, raw' 'Green corn (maize)' 'Groundnuts, excluding shelled'
#  'Hen eggs in shell, fresh' 'Horse meat, fresh or chilled'
#  'Horse meat, fresh or chilled (biological)'
#  'Leeks and other alliaceous vegetables' 'Lemons and limes'
#  'Lettuce and chicory' 'Maize (corn)' 'Mangoes, guavas and mangosteens'
#  'Meat of buffalo, fresh or chilled'
#  'Meat of buffalo, fresh or chilled (biological)'
#  'Meat of cattle with the bone, fresh or chilled'
#  'Meat of cattle with the bone, fresh or chilled (biological)'
#  'Meat of chickens, fresh or chilled'
#  'Meat of chickens, fresh or chilled (biological)'
#  'Meat of ducks, fresh or chilled'
#  'Meat of ducks, fresh or chilled (biological)'
#  'Meat of goat, fresh or chilled'
#  'Meat of goat, fresh or chilled (biological)'
#  'Meat of pig with the bone, fresh or chilled'
#  'Meat of pig with the bone, fresh or chilled (biological)'
#  'Meat of sheep, fresh or chilled'
#  'Meat of sheep, fresh or chilled (biological)'
#  'Natural rubber in primary forms' 'Nutmeg, mace, cardamoms, raw'
#  'Oil palm fruit' 'Okra' 'Oranges'
#  'Other bananas (excluding cavendish and cooking bananas)'
#  'Other citrus fruit, n.e.c.' 'Other vegetables, fresh n.e.c.'
#  'Palm kernels' 'Palm oil' 'Papayas' 'Pepper (Piper spp.), raw'
#  'Pineapples' 'Pomelos and grapefruits' 'Pumpkins, squash and gourds'
#  'Raw milk of buffalo' 'Raw milk of cattle' 'Rice'
#  'Shorn wool, greasy, including fleece-washed shorn wool' 'Soya beans'
#  'Spinach' 'Sugar cane' 'Sweet potatoes'
#  'Tangerines, mandarins, clementines' 'Tea leaves' 'Tomatoes'
#  'Unmanufactured tobacco' 'Watermelons' 'Yams' 'Agriculture'
#  'Cereals, primary' 'Citrus Fruit, Total' 'Coarse Grain, Total'
#  'Eggs Primary' 'Fruit excl Melons, Total' 'Fruit Primary' 'Livestock'
#  'Meat, Total' 'Milk, Total' 'Oilcrops, Oil Equivalent'
#  'Roots and Tubers, Total' 'Treenuts, Total' 'Vegetables Primary'
#  'Vegetables&Melons, Total']

# %%
# Filter only Producer Price Index entries
df = df[df['Element'] == 'Producer Price Index (2014-2016 = 100)'].copy()

# Convert 'Value' to numeric and drop invalid entries
df['Value'] = pd.to_numeric(df['Value'], errors='coerce')
df = df.dropna(subset=['Value', 'Year'])

# -------------------------------
# Classify Items by Food Category
# -------------------------------

# Define detailed keywords
plant_keywords = [
    "vegetable", "legume", "fruit", "cruciferous", "greens", "beans",
    "nuts", "seeds", "herb", "spices", "whole grain", "maize", "cassava", "ginger",
    "lettuce", "mangoes", "cabbages", "carrots", "broccoli", "cucumbers",
    "cauliflowers", "bananas", "eggplants", "leeks", "coffee", "cocoa", "coconut",
    "pepper", "asparagus", "corn", "turnips", "chillies", "onion", "garlic"
]

animal_keywords = [
    "meat", "egg", "milk", "dairy", "livestock", "buffalo", "cattle", "chicken", "duck", "goat", "pig", "horse"
]

# Categorization function
def classify_item(item):
    item_lower = str(item).lower()
    if any(k in item_lower for k in plant_keywords):
        return "Plant-Based"
    elif any(k in item_lower for k in animal_keywords):
        return "Animal-Based"
    else:
        return "Other"

# Apply classification
df['Category'] = df['Item'].apply(classify_item)

# -------------------------------
# Aggregate by Year and Category
# -------------------------------
grouped = df[df['Category'].isin(["Plant-Based", "Animal-Based"])]
trend_data = grouped.groupby(['Year', 'Category'])['Value'].mean().unstack()

# -------------------------------
# Plotting
# -------------------------------
plt.figure(figsize=(12, 6))
trend_data.plot(marker='o')
plt.title("Time Series of Producer Price Index in Malaysia by Food Category")
plt.ylabel("Producer Price Index (2014–2016 = 100)")
plt.xlabel("Year")
plt.grid(True)
plt.legend(title="Food Category")
plt.tight_layout()
plt.show()

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("C:/Users/PC/02_Forward School/Capstone Project/00_Datasets/05 Food Price/producer-prices_mys.csv")

# Filter for Producer Price Index data
df = df[df['Element'] == 'Producer Price Index (2014-2016 = 100)'].copy()

# Clean the 'Value' column
df['Value'] = pd.to_numeric(df['Value'], errors='coerce')
df = df.dropna(subset=['Value', 'Year'])

# Define food category keywords
plant_keywords = [
    "vegetable", "legume", "fruit", "cruciferous", "greens", "beans",
    "nuts", "seeds", "herb", "spices", "whole grain", "maize", "cassava", "ginger",
    "lettuce", "mangoes", "cabbages", "carrots", "broccoli", "cucumbers",
    "cauliflowers", "bananas", "eggplants", "leeks", "coffee", "cocoa", "coconut",
    "pepper", "asparagus", "corn", "turnips", "chillies", "onion", "garlic"
]
animal_keywords = [
    "meat", "egg", "milk", "dairy", "livestock", "buffalo", "cattle", "chicken", "duck", "goat", "pig", "horse"
]

# Classify each item
def classify_item(item):
    item_lower = str(item).lower()
    if any(k in item_lower for k in plant_keywords):
        return "Plant-Based"
    elif any(k in item_lower for k in animal_keywords):
        return "Animal-Based"
    else:
        return "Other"

df['Category'] = df['Item'].apply(classify_item)

# Filter only plant and animal-based entries
filtered_df = df[df['Category'].isin(['Plant-Based', 'Animal-Based'])]

avg_price_by_commodity.head(20).reset_index(drop=True).style \
    .format({"Value": "{:.2f}"}) \
    .background_gradient(cmap="YlOrRd", subset="Value") \
    .set_caption("Top 20 Commodities by Average Producer Price Index")
# Out:
# <style type="text/css">
# #T_bf48d_row0_col2 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_bf48d_row1_col2 {
#   background-color: #aa0026;
#   color: #f1f1f1;
# }
# #T_bf48d_row2_col2 {
#   background-color: #d10e21;
#   color: #f1f1f1;
# }
# #T_bf48d_row3_col2 {
#   background-color: #fc5b2e;
#   color: #f1f1f1;
# }
# #T_bf48d_row4_col2 {
#   background-color: #fea044;
#   color: #000000;
# }
# #T_bf48d_row5_col2 {
#   background-color: #fea245;
#   color: #000000;
# }
# #T_bf48d_row6_col2 {
#   background-color: #feae4a;
#   color: #000000;
# }
# #T_bf48d_row7_col2 {
#   background-color: #feb651;
#   color: #000000;
# }
# #T_bf48d_row8_col2 {
#   background-color: #feca66;
#   color: #000000;
# }
# #T_bf48d_row9_col2 {
#   background-color: #ffeb9c;
#   color: #000000;
# }
# #T_bf48d_row10_col2 {
#   background-color: #ffeda1;
#   color: #000000;
# }
# #T_bf48d_row11_col2 {
#   background-color: #fff0a8;
#   color: #000000;
# }
# #T_bf48d_row12_col2 {
#   background-color: #fff3af;
#   color: #000000;
# }
# #T_bf48d_row13_col2 {
#   background-color: #fff5b3;
#   color: #000000;
# }
# #T_bf48d_row14_col2 {
#   background-color: #fff6b6;
#   color: #000000;
# }
# #T_bf48d_row15_col2 {
#   background-color: #fff7b9;
#   color: #000000;
# }
# #T_bf48d_row16_col2 {
#   background-color: #fff8bb;
#   color: #000000;
# }
# #T_bf48d_row17_col2 {
#   background-color: #fff9be;
#   color: #000000;
# }
# #T_bf48d_row18_col2 {
#   background-color: #fffac0;
#   color: #000000;
# }
# #T_bf48d_row19_col2 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# </style>
# <table id="T_bf48d">
#   <caption>Top 20 Commodities by Average Producer Price Index</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bf48d_level0_col0" class="col_heading level0 col0" >Item</th>
#       <th id="T_bf48d_level0_col1" class="col_heading level0 col1" >Category</th>
#       <th id="T_bf48d_level0_col2" class="col_heading level0 col2" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bf48d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bf48d_row0_col0" class="data row0 col0" >Meat of buffalo, fresh or chilled</td>
#       <td id="T_bf48d_row0_col1" class="data row0 col1" >Animal-Based</td>
#       <td id="T_bf48d_row0_col2" class="data row0 col2" >122.15</td>
#     </tr>
#     <tr>
#       <th id="T_bf48d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bf48d_row1_col0" class="data row1 col0" >Lettuce and chicory</td>
#       <td id="T_bf48d_row1_col1" class="data row1 col1" >Plant-Based</td>
#       <td id="T_bf48d_row1_col2" class="data row1 col2" >118.74</td>
#     </tr>
#     <tr>
#       <th id="T_bf48d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bf48d_row2_col0" class="data row2 col0" >Bananas cavendish</td>
#       <td id="T_bf48d_row2_col1" class="data row2 col1" >Plant-Based</td>
#       <td id="T_bf48d_row2_col2" class="data row2 col2" >114.46</td>
#     </tr>
#     <tr>
#       <th id="T_bf48d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_bf48d_row3_col0" class="data row3 col0" >Carrots and turnips</td>
#       <td id="T_bf48d_row3_col1" class="data row3 col1" >Plant-Based</td>
#       <td id="T_bf48d_row3_col2" class="data row3 col2" >106.27</td>
#     </tr>
#     <tr>
#       <th id="T_bf48d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_bf48d_row4_col0" class="data row4 col0" >Green corn (maize)</td>
#       <td id="T_bf48d_row4_col1" class="data row4 col1" >Plant-Based</td>
#       <td id="T_bf48d_row4_col2" class="data row4 col2" >99.85</td>
#     </tr>
#     <tr>
#       <th id="T_bf48d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_bf48d_row5_col0" class="data row5 col0" >Other bananas (excluding cavendish and cooking bananas)</td>
#       <td id="T_bf48d_row5_col1" class="data row5 col1" >Plant-Based</td>
#       <td id="T_bf48d_row5_col2" class="data row5 col2" >99.46</td>
#     </tr>
#     <tr>
#       <th id="T_bf48d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_bf48d_row6_col0" class="data row6 col0" >Cabbages</td>
#       <td id="T_bf48d_row6_col1" class="data row6 col1" >Plant-Based</td>
#       <td id="T_bf48d_row6_col2" class="data row6 col2" >97.92</td>
#     </tr>
#     <tr>
#       <th id="T_bf48d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_bf48d_row7_col0" class="data row7 col0" >Cauliflowers and broccoli</td>
#       <td id="T_bf48d_row7_col1" class="data row7 col1" >Plant-Based</td>
#       <td id="T_bf48d_row7_col2" class="data row7 col2" >96.91</td>
#     </tr>
#     <tr>
#       <th id="T_bf48d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_bf48d_row8_col0" class="data row8 col0" >Meat of sheep, fresh or chilled</td>
#       <td id="T_bf48d_row8_col1" class="data row8 col1" >Animal-Based</td>
#       <td id="T_bf48d_row8_col2" class="data row8 col2" >94.39</td>
#     </tr>
#     <tr>
#       <th id="T_bf48d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_bf48d_row9_col0" class="data row9 col0" >Other citrus fruit, n.e.c.</td>
#       <td id="T_bf48d_row9_col1" class="data row9 col1" >Plant-Based</td>
#       <td id="T_bf48d_row9_col2" class="data row9 col2" >87.98</td>
#     </tr>
#     <tr>
#       <th id="T_bf48d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_bf48d_row10_col0" class="data row10 col0" >Cucumbers and gherkins</td>
#       <td id="T_bf48d_row10_col1" class="data row10 col1" >Plant-Based</td>
#       <td id="T_bf48d_row10_col2" class="data row10 col2" >87.40</td>
#     </tr>
#     <tr>
#       <th id="T_bf48d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_bf48d_row11_col0" class="data row11 col0" >Leeks and other alliaceous vegetables</td>
#       <td id="T_bf48d_row11_col1" class="data row11 col1" >Plant-Based</td>
#       <td id="T_bf48d_row11_col2" class="data row11 col2" >86.67</td>
#     </tr>
#     <tr>
#       <th id="T_bf48d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_bf48d_row12_col0" class="data row12 col0" >Coconuts, in shell</td>
#       <td id="T_bf48d_row12_col1" class="data row12 col1" >Plant-Based</td>
#       <td id="T_bf48d_row12_col2" class="data row12 col2" >85.93</td>
#     </tr>
#     <tr>
#       <th id="T_bf48d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_bf48d_row13_col0" class="data row13 col0" >Chillies and peppers, green (Capsicum spp. and Pimenta spp.)</td>
#       <td id="T_bf48d_row13_col1" class="data row13 col1" >Plant-Based</td>
#       <td id="T_bf48d_row13_col2" class="data row13 col2" >85.47</td>
#     </tr>
#     <tr>
#       <th id="T_bf48d_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_bf48d_row14_col0" class="data row14 col0" >Raw milk of cattle</td>
#       <td id="T_bf48d_row14_col1" class="data row14 col1" >Animal-Based</td>
#       <td id="T_bf48d_row14_col2" class="data row14 col2" >85.15</td>
#     </tr>
#     <tr>
#       <th id="T_bf48d_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_bf48d_row15_col0" class="data row15 col0" >Milk, Total</td>
#       <td id="T_bf48d_row15_col1" class="data row15 col1" >Animal-Based</td>
#       <td id="T_bf48d_row15_col2" class="data row15 col2" >84.79</td>
#     </tr>
#     <tr>
#       <th id="T_bf48d_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_bf48d_row16_col0" class="data row16 col0" >Pomelos and grapefruits</td>
#       <td id="T_bf48d_row16_col1" class="data row16 col1" >Plant-Based</td>
#       <td id="T_bf48d_row16_col2" class="data row16 col2" >84.56</td>
#     </tr>
#     <tr>
#       <th id="T_bf48d_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_bf48d_row17_col0" class="data row17 col0" >Eggplants (aubergines)</td>
#       <td id="T_bf48d_row17_col1" class="data row17 col1" >Plant-Based</td>
#       <td id="T_bf48d_row17_col2" class="data row17 col2" >84.11</td>
#     </tr>
#     <tr>
#       <th id="T_bf48d_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_bf48d_row18_col0" class="data row18 col0" >Meat of buffalo, fresh or chilled (biological)</td>
#       <td

# %%
# Load and clean dataset
df = pd.read_csv("C:/Users/PC/02_Forward School/Capstone Project/00_Datasets/05 Food Price/producer-prices_mys.csv")
df = df[df['Element'] == 'Producer Price Index (2014-2016 = 100)'].copy()
df['Value'] = pd.to_numeric(df['Value'], errors='coerce')
df = df.dropna(subset=['Value', 'Year'])

# Classify items
plant_keywords = [
    "vegetable", "legume", "fruit", "cruciferous", "greens", "beans",
    "nuts", "seeds", "herb", "spices", "whole grain", "maize", "cassava", "ginger",
    "lettuce", "mangoes", "cabbages", "carrots", "broccoli", "cucumbers",
    "cauliflowers", "bananas", "eggplants", "leeks", "coffee", "cocoa", "coconut",
    "pepper", "asparagus", "corn", "turnips", "chillies", "onion", "garlic"
]
animal_keywords = [
    "meat", "egg", "milk", "dairy", "livestock", "buffalo", "cattle", "chicken", "duck", "goat", "pig", "horse"
]

def classify_item(item):
    item_lower = str(item).lower()
    if any(k in item_lower for k in plant_keywords):
        return "Plant-Based"
    elif any(k in item_lower for k in animal_keywords):
        return "Animal-Based"
    else:
        return "Other"

df['Category'] = df['Item'].apply(classify_item)
filtered_df = df[df['Category'].isin(['Plant-Based', 'Animal-Based'])]

# Calculate volatility = standard deviation of price index over years
volatility_df = (
    filtered_df.groupby(['Item', 'Category'])['Value']
    .std()
    .reset_index()
    .rename(columns={'Value': 'Volatility'})
    .sort_values(by='Volatility', ascending=False)
)

# Optional: round for display
volatility_df['Volatility'] = volatility_df['Volatility'].round(2)

# Display top 20 most volatile commodities
from IPython.display import display

# Styled volatility table with gradient coloring
display(
    volatility_df.head(20).reset_index(drop=True).style
        .format({"Volatility": "{:.2f}"})
        .background_gradient(cmap="YlOrRd", subset="Volatility")
        .set_caption("Top 20 Commodities by Price Volatility (Standard Deviation)"))
# Out:
# <style type="text/css">
# #T_12af8_row0_col2 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_12af8_row1_col2 {
#   background-color: #fd9841;
#   color: #000000;
# }
# #T_12af8_row2_col2 {
#   background-color: #fea145;
#   color: #000000;
# }
# #T_12af8_row3_col2 {
#   background-color: #feb852;
#   color: #000000;
# }
# #T_12af8_row4_col2 {
#   background-color: #fed673;
#   color: #000000;
# }
# #T_12af8_row5_col2 {
#   background-color: #fede80;
#   color: #000000;
# }
# #T_12af8_row6_col2, #T_12af8_row7_col2 {
#   background-color: #ffeb9c;
#   color: #000000;
# }
# #T_12af8_row8_col2, #T_12af8_row9_col2 {
#   background-color: #ffefa4;
#   color: #000000;
# }
# #T_12af8_row10_col2 {
#   background-color: #fff1a9;
#   color: #000000;
# }
# #T_12af8_row11_col2 {
#   background-color: #fff2ac;
#   color: #000000;
# }
# #T_12af8_row12_col2, #T_12af8_row13_col2 {
#   background-color: #fff6b6;
#   color: #000000;
# }
# #T_12af8_row14_col2 {
#   background-color: #fff9bd;
#   color: #000000;
# }
# #T_12af8_row15_col2 {
#   background-color: #fff9be;
#   color: #000000;
# }
# #T_12af8_row16_col2 {
#   background-color: #fffac0;
#   color: #000000;
# }
# #T_12af8_row17_col2 {
#   background-color: #fffbc2;
#   color: #000000;
# }
# #T_12af8_row18_col2 {
#   background-color: #fffec9;
#   color: #000000;
# }
# #T_12af8_row19_col2 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# </style>
# <table id="T_12af8">
#   <caption>Top 20 Commodities by Price Volatility (Standard Deviation)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_12af8_level0_col0" class="col_heading level0 col0" >Item</th>
#       <th id="T_12af8_level0_col1" class="col_heading level0 col1" >Category</th>
#       <th id="T_12af8_level0_col2" class="col_heading level0 col2" >Volatility</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_12af8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_12af8_row0_col0" class="data row0 col0" >Meat of buffalo, fresh or chilled</td>
#       <td id="T_12af8_row0_col1" class="data row0 col1" >Animal-Based</td>
#       <td id="T_12af8_row0_col2" class="data row0 col2" >84.83</td>
#     </tr>
#     <tr>
#       <th id="T_12af8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_12af8_row1_col0" class="data row1 col0" >Oil palm fruit</td>
#       <td id="T_12af8_row1_col1" class="data row1 col1" >Plant-Based</td>
#       <td id="T_12af8_row1_col2" class="data row1 col2" >57.43</td>
#     </tr>
#     <tr>
#       <th id="T_12af8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_12af8_row2_col0" class="data row2 col0" >Meat of sheep, fresh or chilled</td>
#       <td id="T_12af8_row2_col1" class="data row2 col1" >Animal-Based</td>
#       <td id="T_12af8_row2_col2" class="data row2 col2" >55.81</td>
#     </tr>
#     <tr>
#       <th id="T_12af8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_12af8_row3_col0" class="data row3 col0" >Lettuce and chicory</td>
#       <td id="T_12af8_row3_col1" class="data row3 col1" >Plant-Based</td>
#       <td id="T_12af8_row3_col2" class="data row3 col2" >52.01</td>
#     </tr>
#     <tr>
#       <th id="T_12af8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_12af8_row4_col0" class="data row4 col0" >Meat of buffalo, fresh or chilled (biological)</td>
#       <td id="T_12af8_row4_col1" class="data row4 col1" >Animal-Based</td>
#       <td id="T_12af8_row4_col2" class="data row4 col2" >47.01</td>
#     </tr>
#     <tr>
#       <th id="T_12af8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_12af8_row5_col0" class="data row5 col0" >Coconuts, in shell</td>
#       <td id="T_12af8_row5_col1" class="data row5 col1" >Plant-Based</td>
#       <td id="T_12af8_row5_col2" class="data row5 col2" >45.00</td>
#     </tr>
#     <tr>
#       <th id="T_12af8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_12af8_row6_col0" class="data row6 col0" >Meat of cattle with the bone, fresh or chilled (biological)</td>
#       <td id="T_12af8_row6_col1" class="data row6 col1" >Animal-Based</td>
#       <td id="T_12af8_row6_col2" class="data row6 col2" >40.85</td>
#     </tr>
#     <tr>
#       <th id="T_12af8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_12af8_row7_col0" class="data row7 col0" >Meat of sheep, fresh or chilled (biological)</td>
#       <td id="T_12af8_row7_col1" class="data row7 col1" >Animal-Based</td>
#       <td id="T_12af8_row7_col2" class="data row7 col2" >40.79</td>
#     </tr>
#     <tr>
#       <th id="T_12af8_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_12af8_row8_col0" class="data row8 col0" >Horse meat, fresh or chilled</td>
#       <td id="T_12af8_row8_col1" class="data row8 col1" >Animal-Based</td>
#       <td id="T_12af8_row8_col2" class="data row8 col2" >39.73</td>
#     </tr>
#     <tr>
#       <th id="T_12af8_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_12af8_row9_col0" class="data row9 col0" >Horse meat, fresh or chilled (biological)</td>
#       <td id="T_12af8_row9_col1" class="data row9 col1" >Animal-Based</td>
#       <td id="T_12af8_row9_col2" class="data row9 col2" >39.72</td>
#     </tr>
#     <tr>
#       <th id="T_12af8_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_12af8_row10_col0" class="data row10 col0" >Ginger, raw</td>
#       <td id="T_12af8_row10_col1" class="data row10 col1" >Plant-Based</td>
#       <td id="T_12af8_row10_col2" class="data row10 col2" >38.76</td>
#     </tr>
#     <tr>
#       <th id="T_12af8_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_12af8_row11_col0" class="data row11 col0" >Chillies and peppers, green (Capsicum spp. and Pimenta spp.)</td>
#       <td id="T_12af8_row11_col1" class="data row11 col1" >Plant-Based</td>
#       <td id="T_12af8_row11_col2" class="data row11 col2" >38.51</td>
#     </tr>
#     <tr>
#       <th id="T_12af8_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_12af8_row12_col0" class="data row12 col0" >Meat of goat, fresh or chilled</td>
#       <td id="T_12af8_row12_col1" class="data row12 col1" >Animal-Based</td>
#       <td id="T_12af8_row12_col2" class="data row12 col2" >37.06</td>
#     </tr>
#     <tr>
#       <th id="T_12af8_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_12af8_row13_col0" class="data row13 col0" >Bananas</td>
#       <td id="T_12af8_row13_col1" class="data row13 col1" >Plant-Based</td>
#       <td id="T_12af8_row13_col2" class="data row13 col2" >36.98</td>
#     </tr>
#     <tr>
#       <th id="T_12af8_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_12af8_row14_col0" class="data row14 col0" >Green corn (maize)</td>
#       <td id="T_12af8_row14_col1" class="data row14 col1" >Plant-Based</td>
#       <td id="T_12af8_row14_col2" class="data row14 col2" >36.13</td>
#     </tr>
#     <tr>
#       <th id="T_12af8_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_12af8_row15_col0" class="data row15 col0" >Meat of goat, fresh or chilled (biological)</td>
#       <td id="T_12af8_row15_col1" class="data row15 col1" >Animal-Based</td>
#       <td id="T_12af8_row15_col2" class="data row15 col2" >35.80</td>
#     </tr>
#     <tr>
#       <th id="T_12af8_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_12af8_row16_col0" class="data row16 col0" >Meat of cattle with the bone, fresh or chilled</td>
#       <td id="T_12af8_row16_col1" class="data row16 col1" >Animal-Based</td>
#       <td id="T_12af8_row16_col2" class="data row16 col2" >35.56</td>
#     </tr>
#     <tr>
#       <th id="T_12af8_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_12af8_row17_col0" class="data row17 col0" >Mangoes, guavas and mangosteens</td>
#       <td id="T_12af8_row17_col1" class="data row17 col1" >Plant-Based</td>
#       <td id="T_12af8_row17_col2" class="data row17 col2" >35.19</td>
#     </tr>
#     <tr>
#       <th id="T_12af8_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_12af8_row18_col0" class="data row18 col0" >Cabbages</td>
#       <td id="T_12af8_row18_col1" class="data row18 col1" >Plant

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("C:/Users/PC/02_Forward School/Capstone Project/00_Datasets/05 Food Price/producer-prices_mys.csv")

# Filter for relevant element
df = df[df['Element'] == 'Producer Price Index (2014-2016 = 100)'].copy()
df['Value'] = pd.to_numeric(df['Value'], errors='coerce')
df = df.dropna(subset=['Value', 'Year'])

# Define keyword-based classification rules
plant_keywords = [
    "vegetable", "legume", "fruit", "cruciferous", "greens", "beans",
    "nuts", "seeds", "herb", "spices", "whole grain", "maize", "cassava", "ginger",
    "lettuce", "mangoes", "cabbages", "carrots", "broccoli", "cucumbers",
    "cauliflowers", "bananas", "eggplants", "leeks", "coffee", "cocoa", "coconut",
    "pepper", "asparagus", "corn", "turnips", "chillies", "onion", "garlic", "okra",
    "spinach", "sweet potatoes", "yams", "rice", "tea", "tomatoes", "tobacco", "pumpkins", "papayas"
]
animal_keywords = [
    "meat", "egg", "milk", "dairy", "livestock", "buffalo", "cattle", "chicken",
    "duck", "goat", "pig", "horse", "wool"
]

# Classification function
def classify_item(item):
    item_lower = str(item).lower()
    if any(k in item_lower for k in plant_keywords):
        return "Plant-Based"
    elif any(k in item_lower for k in animal_keywords):
        return "Animal-Based"
    else:
        return "Other"

df['Category'] = df['Item'].apply(classify_item)

# Reference items to include
reference_items = [ 
    'Areca nuts', 'Asparagus', 'Bananas', 'Bananas cavendish', 'Cabbages', 'Carrots and turnips',
    'Cashew nuts, in shell', 'Cassava, fresh', 'Cauliflowers and broccoli',
    'Chillies and peppers, dry (Capsicum spp., Pimenta spp.), raw',
    'Chillies and peppers, green (Capsicum spp. and Pimenta spp.)',
    'Cloves (whole stems), raw', 'Cocoa beans', 'Coconuts, in shell', 'Coffee, green',
    'Cucumbers and gherkins', 'Edible roots and tubers with high starch or inulin content, n.e.c., fresh',
    'Eggplants (aubergines)', 'Eggs from other birds in shell, fresh, n.e.c.', 'Ginger, raw',
    'Green corn (maize)', 'Groundnuts, excluding shelled', 'Hen eggs in shell, fresh',
    'Horse meat, fresh or chilled', 'Horse meat, fresh or chilled (biological)',
    'Leeks and other alliaceous vegetables', 'Lemons and limes', 'Lettuce and chicory',
    'Maize (corn)', 'Mangoes, guavas and mangosteens', 'Meat of buffalo, fresh or chilled',
    'Meat of buffalo, fresh or chilled (biological)', 'Meat of cattle with the bone, fresh or chilled',
    'Meat of cattle with the bone, fresh or chilled (biological)', 'Meat of chickens, fresh or chilled',
    'Meat of chickens, fresh or chilled (biological)', 'Meat of ducks, fresh or chilled',
    'Meat of ducks, fresh or chilled (biological)', 'Meat of goat, fresh or chilled',
    'Meat of goat, fresh or chilled (biological)', 'Meat of pig with the bone, fresh or chilled',
    'Meat of pig with the bone, fresh or chilled (biological)', 'Meat of sheep, fresh or chilled',
    'Meat of sheep, fresh or chilled (biological)', 'Natural rubber in primary forms',
    'Nutmeg, mace, cardamoms, raw', 'Oil palm fruit', 'Okra', 'Oranges',
    'Other bananas (excluding cavendish and cooking bananas)', 'Other citrus fruit, n.e.c.',
    'Other vegetables, fresh n.e.c.', 'Palm kernels', 'Palm oil', 'Papayas',
    'Pepper (Piper spp.), raw', 'Pineapples', 'Pomelos and grapefruits',
    'Pumpkins, squash and gourds', 'Raw milk of buffalo', 'Raw milk of cattle', 'Rice',
    'Shorn wool, greasy, including fleece-washed shorn wool', 'Soya beans', 'Spinach',
    'Sugar cane', 'Sweet potatoes', 'Tangerines, mandarins, clementines', 'Tea leaves',
    'Tomatoes', 'Unmanufactured tobacco', 'Watermelons', 'Yams'
]

# Filter and calculate average PPI
filtered_df = df[df['Item'].isin(reference_items)]
avg_ppi = (
    filtered_df.groupby(['Item', 'Category'])['Value']
    .mean()
    .reset_index()
    .round({'Value': 2})
    .sort_values(by='Value', ascending=False)
)

# Separate plant-based and animal-based tables
plant_based_table = avg_ppi[avg_ppi['Category'] == 'Plant-Based'].reset_index(drop=True)
animal_based_table = avg_ppi[avg_ppi['Category'] == 'Animal-Based'].reset_index(drop=True)

# Display result
from IPython.display import display
display(plant_based_table)
display(animal_based_table)
# Out:
#                                                  Item     Category   Value
# 0                              Unmanufactured tobacco  Plant-Based  123.96
# 1                                 Lettuce and chicory  Plant-Based  118.74
# 2                                   Bananas cavendish  Plant-Based  114.46
# 3                                 Carrots and turnips  Plant-Based  106.27
# 4                                                Yams  Plant-Based  101.31
# 5                                  Green corn (maize)  Plant-Based   99.85
# 6   Other bananas (excluding cavendish and cooking...  Plant-Based   99.46
# 7                                            Cabbages  Plant-Based   97.92
# 8                           Cauliflowers and broccoli  Plant-Based   96.91
# 9                         Pumpkins, squash and gourds  Plant-Based   88.44
# 10                         Other citrus fruit, n.e.c.  Plant-Based   87.98
# 11                             Cucumbers and gherkins  Plant-Based   87.40
# 12              Leeks and other alliaceous vegetables  Plant-Based   86.67
# 13                                 Coconuts, in shell  Plant-Based   85.93
# 14  Chillies and peppers, green (Capsicum spp. and...  Plant-Based   85.47
# 15                                           Tomatoes  Plant-Based   84.92
# 16                                            Spinach  Plant-Based   84.73
# 17                            Pomelos and grapefruits  Plant-Based   84.56
# 18                             Eggplants (aubergines)  Plant-Based   84.11
# 19                                      Coffee, green  Plant-Based   81.42
# 20                      Groundnuts, excluding shelled  Plant-Based   80.98
# 21                                         Areca nuts  Plant-Based   80.95
# 22                                         Soya beans  Plant-Based   80.81
# 23                                          Asparagus  Plant-Based   80.73
# 24                              Cashew nuts, in shell  Plant-Based   79.66
# 25  Chillies and peppers, dry (Capsicum spp., Pime...  Plant-Based   78.98
# 26                                         Tea leaves  Plant-Based   78.61
# 27                                       Maize (corn)  Plant-Based   77.64
# 28                     Other vegetables, fresh n.e.c.  Plant-Based   77.23
# 29                                               Okra  Plant-Based   76.71
# 30                                     Sweet potatoes  Plant-Based   75.82
# 31                                     Oil palm fruit  Plant-Based   73.66
# 32                                            Papayas  Plant-Based   71.58
# 33                                               Rice  Plant-Based   66.55
# 34                    Mangoes, guavas and mangosteens  Plant-Based   64.59
# 35                                     Cassava, fresh  Plant-Based   63.44
# 36                                        Ginger, raw  Plant-Based   61.12
# 37                                            Bananas  Plant-Based   60.87
# 38                                        Cocoa beans  Plant-Based   60.45
# 39                           Pepper (Piper spp.), raw  Plant-Based   59.88
#                                                  Item      Category   Value
# 0                   Meat of buffalo, fresh or chilled  Animal-Based  122.15
# 1                     Meat of sheep, fresh or chilled  Animal-Based   94.39
# 2                                  Raw milk of cattle  Animal-Based   85.15
# 3      Meat of buffalo, fresh or chilled (biological)  Animal-Based   84.09
# 4                                 Raw milk of buffalo  Animal-Based   82.56
# 5                      Meat of goat, fresh or chilled  Animal-Based   80.66
# 6     Meat of chickens, fresh or chilled (biological)  Animal-Based   80.49
# 7      Meat of cattle with the bone, fresh or chilled  Animal-Based   80.22
# 8       Eggs from other birds in shell, fresh, n.e.c.  Animal-Based   80.11
# 9   Shorn wool, greasy, including fleece-washed sh...  Animal-Based   76.71
# 10                           Hen eggs in shell, fresh  Animal-Based   76.20
# 11                 Meat of chickens, fresh or chilled  Animal-Based   74.81
# 12        Meat of pig with the bone, fresh or chilled  Animal-Based   74.28
# 13  Meat of pig with the bone, fresh or chilled (b...  Animal-Based   73.78
# 14  Meat of cattle with the bone, fresh or chilled...  Animal-Based   72.90
# 15          Horse meat, fresh or chilled (biological)  Animal-Based   71.78
# 16                       Horse meat, fresh or chilled  Animal-Based   71.78
# 17       Meat of sheep, fresh or chilled (biological)  Animal-Based   71.10
# 18                    Meat of ducks, fresh or chilled  Animal-Based   69.41
# 19        Meat of goat, fresh or chilled (biological)  Animal-Based   66.02
# 20       Meat of ducks, fresh or chilled (biological)  Animal-Based   65.29

# %%
from IPython.display import display

# Plant-Based Table
print("🌱 Plant-Based Items with Average Producer Price Index")
display(
    plant_based_table.style
        .format({"Value": "{:.2f}"})
        .background_gradient(cmap="OrRd", subset="Value")
        .set_caption("Plant-Based Items - Average Producer Price Index")
)

# Animal-Based Table
print("\n🍖 Animal-Based Items with Average Producer Price Index")
display(
    animal_based_table.style
        .format({"Value": "{:.2f}"})
        .background_gradient(cmap="OrRd", subset="Value")
        .set_caption("Animal-Based Items - Average Producer Price Index")
)
# Out:
# 🌱 Plant-Based Items with Average Producer Price Index
# <style type="text/css">
# #T_9a296_row0_col2 {
#   background-color: #7f0000;
#   color: #f1f1f1;
# }
# #T_9a296_row1_col2 {
#   background-color: #a00000;
#   color: #f1f1f1;
# }
# #T_9a296_row2_col2 {
#   background-color: #b90805;
#   color: #f1f1f1;
# }
# #T_9a296_row3_col2 {
#   background-color: #dc3a27;
#   color: #f1f1f1;
# }
# #T_9a296_row4_col2 {
#   background-color: #eb5c41;
#   color: #f1f1f1;
# }
# #T_9a296_row5_col2 {
#   background-color: #ef6548;
#   color: #f1f1f1;
# }
# #T_9a296_row6_col2 {
#   background-color: #f06749;
#   color: #f1f1f1;
# }
# #T_9a296_row7_col2 {
#   background-color: #f2704c;
#   color: #f1f1f1;
# }
# #T_9a296_row8_col2 {
#   background-color: #f4754f;
#   color: #f1f1f1;
# }
# #T_9a296_row9_col2 {
#   background-color: #fca06b;
#   color: #000000;
# }
# #T_9a296_row10_col2 {
#   background-color: #fca36e;
#   color: #000000;
# }
# #T_9a296_row11_col2 {
#   background-color: #fda872;
#   color: #000000;
# }
# #T_9a296_row12_col2 {
#   background-color: #fdab75;
#   color: #000000;
# }
# #T_9a296_row13_col2 {
#   background-color: #fdaf79;
#   color: #000000;
# }
# #T_9a296_row14_col2 {
#   background-color: #fdb27b;
#   color: #000000;
# }
# #T_9a296_row15_col2 {
#   background-color: #fdb57e;
#   color: #000000;
# }
# #T_9a296_row16_col2 {
#   background-color: #fdb67f;
#   color: #000000;
# }
# #T_9a296_row17_col2 {
#   background-color: #fdb881;
#   color: #000000;
# }
# #T_9a296_row18_col2 {
#   background-color: #fdba83;
#   color: #000000;
# }
# #T_9a296_row19_col2 {
#   background-color: #fdc38c;
#   color: #000000;
# }
# #T_9a296_row20_col2, #T_9a296_row21_col2 {
#   background-color: #fdc48d;
#   color: #000000;
# }
# #T_9a296_row22_col2, #T_9a296_row23_col2 {
#   background-color: #fdc58e;
#   color: #000000;
# }
# #T_9a296_row24_col2 {
#   background-color: #fdc892;
#   color: #000000;
# }
# #T_9a296_row25_col2 {
#   background-color: #fdca94;
#   color: #000000;
# }
# #T_9a296_row26_col2 {
#   background-color: #fdcc96;
#   color: #000000;
# }
# #T_9a296_row27_col2 {
#   background-color: #fdcf99;
#   color: #000000;
# }
# #T_9a296_row28_col2 {
#   background-color: #fdd09a;
#   color: #000000;
# }
# #T_9a296_row29_col2 {
#   background-color: #fdd19b;
#   color: #000000;
# }
# #T_9a296_row30_col2 {
#   background-color: #fdd49f;
#   color: #000000;
# }
# #T_9a296_row31_col2 {
#   background-color: #fdd9aa;
#   color: #000000;
# }
# #T_9a296_row32_col2 {
#   background-color: #fedfb5;
#   color: #000000;
# }
# #T_9a296_row33_col2 {
#   background-color: #feebcf;
#   color: #000000;
# }
# #T_9a296_row34_col2 {
#   background-color: #feefd8;
#   color: #000000;
# }
# #T_9a296_row35_col2 {
#   background-color: #fff0dc;
#   color: #000000;
# }
# #T_9a296_row36_col2 {
#   background-color: #fff5e7;
#   color: #000000;
# }
# #T_9a296_row37_col2 {
#   background-color: #fff6e9;
#   color: #000000;
# }
# #T_9a296_row38_col2 {
#   background-color: #fff6ea;
#   color: #000000;
# }
# #T_9a296_row39_col2 {
#   background-color: #fff7ec;
#   color: #000000;
# }
# </style>
# <table id="T_9a296">
#   <caption>Plant-Based Items - Average Producer Price Index</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9a296_level0_col0" class="col_heading level0 col0" >Item</th>
#       <th id="T_9a296_level0_col1" class="col_heading level0 col1" >Category</th>
#       <th id="T_9a296_level0_col2" class="col_heading level0 col2" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9a296_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9a296_row0_col0" class="data row0 col0" >Unmanufactured tobacco</td>
#       <td id="T_9a296_row0_col1" class="data row0 col1" >Plant-Based</td>
#       <td id="T_9a296_row0_col2" class="data row0 col2" >123.96</td>
#     </tr>
#     <tr>
#       <th id="T_9a296_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9a296_row1_col0" class="data row1 col0" >Lettuce and chicory</td>
#       <td id="T_9a296_row1_col1" class="data row1 col1" >Plant-Based</td>
#       <td id="T_9a296_row1_col2" class="data row1 col2" >118.74</td>
#     </tr>
#     <tr>
#       <th id="T_9a296_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9a296_row2_col0" class="data row2 col0" >Bananas cavendish</td>
#       <td id="T_9a296_row2_col1" class="data row2 col1" >Plant-Based</td>
#       <td id="T_9a296_row2_col2" class="data row2 col2" >114.46</td>
#     </tr>
#     <tr>
#       <th id="T_9a296_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9a296_row3_col0" class="data row3 col0" >Carrots and turnips</td>
#       <td id="T_9a296_row3_col1" class="data row3 col1" >Plant-Based</td>
#       <td id="T_9a296_row3_col2" class="data row3 col2" >106.27</td>
#     </tr>
#     <tr>
#       <th id="T_9a296_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9a296_row4_col0" class="data row4 col0" >Yams</td>
#       <td id="T_9a296_row4_col1" class="data row4 col1" >Plant-Based</td>
#       <td id="T_9a296_row4_col2" class="data row4 col2" >101.31</td>
#     </tr>
#     <tr>
#       <th id="T_9a296_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9a296_row5_col0" class="data row5 col0" >Green corn (maize)</td>
#       <td id="T_9a296_row5_col1" class="data row5 col1" >Plant-Based</td>
#       <td id="T_9a296_row5_col2" class="data row5 col2" >99.85</td>
#     </tr>
#     <tr>
#       <th id="T_9a296_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9a296_row6_col0" class="data row6 col0" >Other bananas (excluding cavendish and cooking bananas)</td>
#       <td id="T_9a296_row6_col1" class="data row6 col1" >Plant-Based</td>
#       <td id="T_9a296_row6_col2" class="data row6 col2" >99.46</td>
#     </tr>
#     <tr>
#       <th id="T_9a296_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9a296_row7_col0" class="data row7 col0" >Cabbages</td>
#       <td id="T_9a296_row7_col1" class="data row7 col1" >Plant-Based</td>
#       <td id="T_9a296_row7_col2" class="data row7 col2" >97.92</td>
#     </tr>
#     <tr>
#       <th id="T_9a296_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9a296_row8_col0" class="data row8 col0" >Cauliflowers and broccoli</td>
#       <td id="T_9a296_row8_col1" class="data row8 col1" >Plant-Based</td>
#       <td id="T_9a296_row8_col2" class="data row8 col2" >96.91</td>
#     </tr>
#     <tr>
#       <th id="T_9a296_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9a296_row9_col0" class="data row9 col0" >Pumpkins, squash and gourds</td>
#       <td id="T_9a296_row9_col1" class="data row9 col1" >Plant-Based</td>
#       <td id="T_9a296_row9_col2" class="data row9 col2" >88.44</td>
#     </tr>
#     <tr>
#       <th id="T_9a296_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_9a296_row10_col0" class="data row10 col0" >Other citrus fruit, n.e.c.</td>
#       <td id="T_9a296_row10_col1" class="data row10 col1" >Plant-Based</td>
#       <td id="T_9a296_row10_col2" class="data row10 col2" >87.98</td>
#     </tr>
#     <tr>
#       <th id="T_9a296_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_9a296_row11_col0" class="data row11 col0" >Cucumbers and gherkins</td>
#       <td id="T_9a296_row11_col1" class="data row11 col1" >Plant-Based</td>
#       <td id="T_9a296_row11_col2" class="data row11 col2" >87.40</td>
#     </tr>
#     <tr>
#       <th id="T_9a296_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_9a296_row12_col0" class="data row12 col0" >Leeks and other alliaceous vegetables</td>
#       <td id="T_9a296_row12_col1" class="data row12 col1" >Plant-Based</td>
#       <td id="T_9a296_row12_col2" class="data row12 col2" >86.67</td>
#     </tr>
#     <tr>
#       <th id="T_9a296_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_9a296_row13_col0" class="data row13 col0" >Coconuts, in shell</td>
#       <td id="T_9a296_row13_col1" class="data row13 col1" >Plant-Based</td>
#       <td id="T_9a296_row13_col2" class="data row13 col2" >85.93</td>
#     </tr>
#     <tr>
#       <th id="T_9a296_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_9a296_row14_col0" class="data row14 col0" >Chillies and peppers, green (Capsicum spp. and Pimenta spp.)</td>
#       <td id="T_9a296_row14_col1" class="data row14 col1"
# 🍖 Animal-Based Items with Average Producer Price Index
# <style type="text/css">
# #T_a2080_row0_col2 {
#   background-color: #7f0000;
#   color: #f1f1f1;
# }
# #T_a2080_row1_col2 {
#   background-color: #fb8957;
#   color: #f1f1f1;
# }
# #T_a2080_row2_col2 {
#   background-color: #fdc089;
#   color: #000000;
# }
# #T_a2080_row3_col2 {
#   background-color: #fdc48d;
#   color: #000000;
# }
# #T_a2080_row4_col2 {
#   background-color: #fdca93;
#   color: #000000;
# }
# #T_a2080_row5_col2 {
#   background-color: #fdd09a;
#   color: #000000;
# }
# #T_a2080_row6_col2, #T_a2080_row7_col2 {
#   background-color: #fdd19b;
#   color: #000000;
# }
# #T_a2080_row8_col2 {
#   background-color: #fdd29c;
#   color: #000000;
# }
# #T_a2080_row9_col2 {
#   background-color: #fddcaf;
#   color: #000000;
# }
# #T_a2080_row10_col2 {
#   background-color: #fdddb1;
#   color: #000000;
# }
# #T_a2080_row11_col2 {
#   background-color: #fee2bb;
#   color: #000000;
# }
# #T_a2080_row12_col2 {
#   background-color: #fee3bd;
#   color: #000000;
# }
# #T_a2080_row13_col2 {
#   background-color: #fee4c0;
#   color: #000000;
# }
# #T_a2080_row14_col2 {
#   background-color: #fee7c5;
#   color: #000000;
# }
# #T_a2080_row15_col2, #T_a2080_row16_col2 {
#   background-color: #fee9cb;
#   color: #000000;
# }
# #T_a2080_row17_col2 {
#   background-color: #feebcf;
#   color: #000000;
# }
# #T_a2080_row18_col2 {
#   background-color: #feefd8;
#   color: #000000;
# }
# #T_a2080_row19_col2 {
#   background-color: #fff6e9;
#   color: #000000;
# }
# #T_a2080_row20_col2 {
#   background-color: #fff7ec;
#   color: #000000;
# }
# </style>
# <table id="T_a2080">
#   <caption>Animal-Based Items - Average Producer Price Index</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a2080_level0_col0" class="col_heading level0 col0" >Item</th>
#       <th id="T_a2080_level0_col1" class="col_heading level0 col1" >Category</th>
#       <th id="T_a2080_level0_col2" class="col_heading level0 col2" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a2080_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a2080_row0_col0" class="data row0 col0" >Meat of buffalo, fresh or chilled</td>
#       <td id="T_a2080_row0_col1" class="data row0 col1" >Animal-Based</td>
#       <td id="T_a2080_row0_col2" class="data row0 col2" >122.15</td>
#     </tr>
#     <tr>
#       <th id="T_a2080_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a2080_row1_col0" class="data row1 col0" >Meat of sheep, fresh or chilled</td>
#       <td id="T_a2080_row1_col1" class="data row1 col1" >Animal-Based</td>
#       <td id="T_a2080_row1_col2" class="data row1 col2" >94.39</td>
#     </tr>
#     <tr>
#       <th id="T_a2080_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a2080_row2_col0" class="data row2 col0" >Raw milk of cattle</td>
#       <td id="T_a2080_row2_col1" class="data row2 col1" >Animal-Based</td>
#       <td id="T_a2080_row2_col2" class="data row2 col2" >85.15</td>
#     </tr>
#     <tr>
#       <th id="T_a2080_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a2080_row3_col0" class="data row3 col0" >Meat of buffalo, fresh or chilled (biological)</td>
#       <td id="T_a2080_row3_col1" class="data row3 col1" >Animal-Based</td>
#       <td id="T_a2080_row3_col2" class="data row3 col2" >84.09</td>
#     </tr>
#     <tr>
#       <th id="T_a2080_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a2080_row4_col0" class="data row4 col0" >Raw milk of buffalo</td>
#       <td id="T_a2080_row4_col1" class="data row4 col1" >Animal-Based</td>
#       <td id="T_a2080_row4_col2" class="data row4 col2" >82.56</td>
#     </tr>
#     <tr>
#       <th id="T_a2080_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a2080_row5_col0" class="data row5 col0" >Meat of goat, fresh or chilled</td>
#       <td id="T_a2080_row5_col1" class="data row5 col1" >Animal-Based</td>
#       <td id="T_a2080_row5_col2" class="data row5 col2" >80.66</td>
#     </tr>
#     <tr>
#       <th id="T_a2080_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a2080_row6_col0" class="data row6 col0" >Meat of chickens, fresh or chilled (biological)</td>
#       <td id="T_a2080_row6_col1" class="data row6 col1" >Animal-Based</td>
#       <td id="T_a2080_row6_col2" class="data row6 col2" >80.49</td>
#     </tr>
#     <tr>
#       <th id="T_a2080_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a2080_row7_col0" class="data row7 col0" >Meat of cattle with the bone, fresh or chilled</td>
#       <td id="T_a2080_row7_col1" class="data row7 col1" >Animal-Based</td>
#       <td id="T_a2080_row7_col2" class="data row7 col2" >80.22</td>
#     </tr>
#     <tr>
#       <th id="T_a2080_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a2080_row8_col0" class="data row8 col0" >Eggs from other birds in shell, fresh, n.e.c.</td>
#       <td id="T_a2080_row8_col1" class="data row8 col1" >Animal-Based</td>
#       <td id="T_a2080_row8_col2" class="data row8 col2" >80.11</td>
#     </tr>
#     <tr>
#       <th id="T_a2080_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a2080_row9_col0" class="data row9 col0" >Shorn wool, greasy, including fleece-washed shorn wool</td>
#       <td id="T_a2080_row9_col1" class="data row9 col1" >Animal-Based</td>
#       <td id="T_a2080_row9_col2" class="data row9 col2" >76.71</td>
#     </tr>
#     <tr>
#       <th id="T_a2080_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a2080_row10_col0" class="data row10 col0" >Hen eggs in shell, fresh</td>
#       <td id="T_a2080_row10_col1" class="data row10 col1" >Animal-Based</td>
#       <td id="T_a2080_row10_col2" class="data row10 col2" >76.20</td>
#     </tr>
#     <tr>
#       <th id="T_a2080_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a2080_row11_col0" class="data row11 col0" >Meat of chickens, fresh or chilled</td>
#       <td id="T_a2080_row11_col1" class="data row11 col1" >Animal-Based</td>
#       <td id="T_a2080_row11_col2" class="data row11 col2" >74.81</td>
#     </tr>
#     <tr>
#       <th id="T_a2080_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_a2080_row12_col0" class="data row12 col0" >Meat of pig with the bone, fresh or chilled</td>
#       <td id="T_a2080_row12_col1" class="data row12 col1" >Animal-Based</td>
#       <td id="T_a2080_row12_col2" class="data row12 col2" >74.28</td>
#     </tr>
#     <tr>
#       <th id="T_a2080_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_a2080_row13_col0" class="data row13 col0" >Meat of pig with the bone, fresh or chilled (biological)</td>
#       <td id="T_a2080_row13_col1" class="data row13 col1" >Animal-Based</td>
#       <td id="T_a2080_row13_col2" class="data row13 col2" >73.78</td>
#     </tr>
#     <tr>
#       <th id="T_a2080_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_a2080_row14_col0" class="data row14 col0" >Meat of cattle with the bone, fresh or chilled (biological)</td>
#       <td id="T_a2080_row14_col1" class="data row14 col1" >Animal-Based</td>
#       <td id="T_a2080_row14_col2" class="data row14 col2" >72.90</td>
#     </tr>
#     <tr>
#       <th id="T_a2080_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_a2080_row15_col0" class="data row15 col0" >Horse meat, fresh or chilled (biological)</td>
#       <td id="T_a2080_row15_col1" class="data row15 col1" >Animal-Based</td>
#       <td id="T_a2080_row15_col2" class="data row15 col2" >71.78</td>
#     </tr>
#     <tr>
#       <th id="T_a2080_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_a2080_row16_col0" class="data row16 col0" >Horse meat, fresh or chilled</td>
#       <td id="T_a2080_row16_col1" class="data row16 col1" >Animal-Based</td>
#       <td id="T_a2080_row16_col2" class="data row16 col2" >71.78</td>
#     </tr>
#     <tr>
#       <th id="T_a2080_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_a2080_row17_col0" class="data row17 col0" >Meat of sheep, fresh or chilled (biological)</td>
#       <td id="T_a2080_row17_col1" class="data row17 col1" >Animal-Based</td>
#       <td id="T_a2080_row17_col2" class="data row17 col2" >71.10</td>
