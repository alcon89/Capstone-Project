# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
price_data = pd.read_csv("C:/Users/PC/02_Forward School/Capstone Project-Alcon Marshall/00_Datasets/05 Food Price/producer-prices_mys.csv", skiprows=1)

# %%
price_data
# Out:
#       #country+code #date+start   #date+end  Unnamed: 3 Unnamed: 4  \
# 0               MYS  1991-01-01  1991-12-31         131       '458
# 1               MYS  1992-01-01  1992-12-31         131       '458
# 2               MYS  1993-01-01  1993-12-31         131       '458
# 3               MYS  1994-01-01  1994-12-31         131       '458
# 4               MYS  1995-01-01  1995-12-31         131       '458
# ...             ...         ...         ...         ...        ...
# 11594           MYS  2020-01-01  2020-12-31         131       '458
# 11595           MYS  2021-01-01  2021-12-31         131       '458
# 11596           MYS  2022-01-01  2022-12-31         131       '458
# 11597           MYS  2023-01-01  2023-12-31         131       '458
# 11598           MYS  2024-01-01  2024-12-31         131       '458
#
#       #country+name  #indicator+code Unnamed: 7           #indicator+name  \
# 0          Malaysia              226  '01379.01                Areca nuts
# 1          Malaysia              226  '01379.01                Areca nuts
# 2          Malaysia              226  '01379.01                Areca nuts
# 3          Malaysia              226  '01379.01                Areca nuts
# 4          Malaysia              226  '01379.01                Areca nuts
# ...             ...              ...        ...                       ...
# 11594      Malaysia             1800     'F1800  Vegetables&Melons, Total
# 11595      Malaysia             1800     'F1800  Vegetables&Melons, Total
# 11596      Malaysia             1800     'F1800  Vegetables&Melons, Total
# 11597      Malaysia             1800     'F1800  Vegetables&Melons, Total
# 11598      Malaysia             1800     'F1800  Vegetables&Melons, Total
#
#        Unnamed: 9                             Unnamed: 10  Unnamed: 11  \
# 0            5539  Producer Price Index (2014-2016 = 100)         1991
# 1            5539  Producer Price Index (2014-2016 = 100)         1992
# 2            5539  Producer Price Index (2014-2016 = 100)         1993
# 3            5539  Producer Price Index (2014-2016 = 100)         1994
# 4            5539  Producer Price Index (2014-2016 = 100)         1995
# ...           ...                                     ...          ...
# 11594        5539  Producer Price Index (2014-2016 = 100)         2020
# 11595        5539  Producer Price Index (2014-2016 = 100)         2021
# 11596        5539  Producer Price Index (2014-2016 = 100)         2022
# 11597        5539  Producer Price Index (2014-2016 = 100)         2023
# 11598        5539  Producer Price Index (2014-2016 = 100)         2024
#
#        #date+year  Unnamed: 13   Unnamed: 14 #indicator+type  \
# 0            1991         7021  Annual value             NaN
# 1            1992         7021  Annual value             NaN
# 2            1993         7021  Annual value             NaN
# 3            1994         7021  Annual value             NaN
# 4            1995         7021  Annual value             NaN
# ...           ...          ...           ...             ...
# 11594        2020         7021  Annual value             NaN
# 11595        2021         7021  Annual value             NaN
# 11596        2022         7021  Annual value             NaN
# 11597        2023         7021  Annual value             NaN
# 11598        2024         7021  Annual value             NaN
#
#        #indicator+value+num Unnamed: 17
# 0                     43.06           I
# 1                     43.30           I
# 2                     43.91           I
# 3                     44.59           I
# 4                     45.01           I
# ...                     ...         ...
# 11594                114.07           I
# 11595                127.45           I
# 11596                149.72           I
# 11597                138.68           I
# 11598                144.78           I
#
# [11599 rows x 18 columns]

# %%
# Replace inf/-inf with NaN
plant_trends.replace([np.inf, -np.inf], np.nan, inplace=True)

# Drop rows with NaN values in 'Value'
plant_trends = plant_trends.dropna(subset=["Value"])

# %%
# Rename columns manually
price_data.columns = [
    "Iso3", "StartDate", "EndDate", "Area_Code", "Area_Code_M49", "Area",
    "Item_Code", "Item_CPC_Code", "Commodity", "Element_Code", "Element",
    "Year_Code", "Year", "Months_Code", "Months", "Unit", "Value", "Flag"
]

# %%
# Filter for Producer Price entries
price_data = price_data[
    price_data["Element"].str.contains("Producer Price", case=False, na=False)
].copy()

# %%
# Convert to numeric
price_data["Value"] = pd.to_numeric(price_data["Value"], errors='coerce')
price_data["Year"] = pd.to_numeric(price_data["Year"], errors='coerce')

# %%
# Drop rows with missing key values
price_data = price_data.dropna(subset=["Commodity", "Year", "Value"])

# %%
# Compute average and round to 0 decimals
avg_prices = price_data.groupby("Commodity")["Value"].mean().reset_index()
avg_prices.columns = ["Commodity", "Avg Producer Price Index"]

# %%
# Round values and format with comma separator
avg_prices["Avg Producer Price Index"] = avg_prices["Avg Producer Price Index"].round(0).astype(int)
avg_prices = avg_prices.sort_values(by="Avg Producer Price Index", ascending=False).reset_index(drop=True)

# %%
# Format with thousands separator and align right
styled_table = avg_prices.style \
    .format({"Avg Producer Price Index": "{:,.0f}"}) \
    .set_properties(subset=["Avg Producer Price Index"], **{'text-align': 'right'}) \
    .set_caption("Average Producer Price Index by Commodity (2014–2016 = 100)") \
    .hide(axis='index')  # Optional: hide index column for clarity

# Display styled table
display(styled_table)
# Out:
# <style type="text/css">
# #T_800a5_row0_col1, #T_800a5_row1_col1, #T_800a5_row2_col1, #T_800a5_row3_col1, #T_800a5_row4_col1, #T_800a5_row5_col1, #T_800a5_row6_col1, #T_800a5_row7_col1, #T_800a5_row8_col1, #T_800a5_row9_col1, #T_800a5_row10_col1, #T_800a5_row11_col1, #T_800a5_row12_col1, #T_800a5_row13_col1, #T_800a5_row14_col1, #T_800a5_row15_col1, #T_800a5_row16_col1, #T_800a5_row17_col1, #T_800a5_row18_col1, #T_800a5_row19_col1, #T_800a5_row20_col1, #T_800a5_row21_col1, #T_800a5_row22_col1, #T_800a5_row23_col1, #T_800a5_row24_col1, #T_800a5_row25_col1, #T_800a5_row26_col1, #T_800a5_row27_col1, #T_800a5_row28_col1, #T_800a5_row29_col1, #T_800a5_row30_col1, #T_800a5_row31_col1, #T_800a5_row32_col1, #T_800a5_row33_col1, #T_800a5_row34_col1, #T_800a5_row35_col1, #T_800a5_row36_col1, #T_800a5_row37_col1, #T_800a5_row38_col1, #T_800a5_row39_col1, #T_800a5_row40_col1, #T_800a5_row41_col1, #T_800a5_row42_col1, #T_800a5_row43_col1, #T_800a5_row44_col1, #T_800a5_row45_col1, #T_800a5_row46_col1, #T_800a5_row47_col1, #T_800a5_row48_col1, #T_800a5_row49_col1, #T_800a5_row50_col1, #T_800a5_row51_col1, #T_800a5_row52_col1, #T_800a5_row53_col1, #T_800a5_row54_col1, #T_800a5_row55_col1, #T_800a5_row56_col1, #T_800a5_row57_col1, #T_800a5_row58_col1, #T_800a5_row59_col1, #T_800a5_row60_col1, #T_800a5_row61_col1, #T_800a5_row62_col1, #T_800a5_row63_col1, #T_800a5_row64_col1, #T_800a5_row65_col1, #T_800a5_row66_col1, #T_800a5_row67_col1, #T_800a5_row68_col1, #T_800a5_row69_col1, #T_800a5_row70_col1, #T_800a5_row71_col1, #T_800a5_row72_col1, #T_800a5_row73_col1, #T_800a5_row74_col1, #T_800a5_row75_col1, #T_800a5_row76_col1, #T_800a5_row77_col1, #T_800a5_row78_col1, #T_800a5_row79_col1, #T_800a5_row80_col1, #T_800a5_row81_col1, #T_800a5_row82_col1, #T_800a5_row83_col1, #T_800a5_row84_col1, #T_800a5_row85_col1, #T_800a5_row86_col1, #T_800a5_row87_col1 {
#   text-align: right;
# }
# </style>
# <table id="T_800a5">
#   <caption>Average Producer Price Index by Commodity (2014–2016 = 100)</caption>
#   <thead>
#     <tr>
#       <th id="T_800a5_level0_col0" class="col_heading level0 col0" >Commodity</th>
#       <th id="T_800a5_level0_col1" class="col_heading level0 col1" >Avg Producer Price Index</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_800a5_row0_col0" class="data row0 col0" >Meat of goat, fresh or chilled (biological)</td>
#       <td id="T_800a5_row0_col1" class="data row0 col1" >13,523</td>
#     </tr>
#     <tr>
#       <td id="T_800a5_row1_col0" class="data row1 col0" >Meat of sheep, fresh or chilled (biological)</td>
#       <td id="T_800a5_row1_col1" class="data row1 col1" >13,202</td>
#     </tr>
#     <tr>
#       <td id="T_800a5_row2_col0" class="data row2 col0" >Meat of goat, fresh or chilled</td>
#       <td id="T_800a5_row2_col1" class="data row2 col1" >11,899</td>
#     </tr>
#     <tr>
#       <td id="T_800a5_row3_col0" class="data row3 col0" >Pepper (Piper spp.), raw</td>
#       <td id="T_800a5_row3_col1" class="data row3 col1" >11,861</td>
#     </tr>
#     <tr>
#       <td id="T_800a5_row4_col0" class="data row4 col0" >Asparagus</td>
#       <td id="T_800a5_row4_col1" class="data row4 col1" >10,452</td>
#     </tr>
#     <tr>
#       <td id="T_800a5_row5_col0" class="data row5 col0" >Meat of cattle with the bone, fresh or chilled</td>
#       <td id="T_800a5_row5_col1" class="data row5 col1" >9,271</td>
#     </tr>
#     <tr>
#       <td id="T_800a5_row6_col0" class="data row6 col0" >Unmanufactured tobacco</td>
#       <td id="T_800a5_row6_col1" class="data row6 col1" >8,630</td>
#     </tr>
#     <tr>
#       <td id="T_800a5_row7_col0" class="data row7 col0" >Meat of buffalo, fresh or chilled (biological)</td>
#       <td id="T_800a5_row7_col1" class="data row7 col1" >8,206</td>
#     </tr>
#     <tr>
#       <td id="T_800a5_row8_col0" class="data row8 col0" >Meat of cattle with the bone, fresh or chilled (biological)</td>
#       <td id="T_800a5_row8_col1" class="data row8 col1" >8,021</td>
#     </tr>
#     <tr>
#       <td id="T_800a5_row9_col0" class="data row9 col0" >Meat of sheep, fresh or chilled</td>
#       <td id="T_800a5_row9_col1" class="data row9 col1" >6,419</td>
#     </tr>
#     <tr>
#       <td id="T_800a5_row10_col0" class="data row10 col0" >Meat of buffalo, fresh or chilled</td>
#       <td id="T_800a5_row10_col1" class="data row10 col1" >6,370</td>
#     </tr>
#     <tr>
#       <td id="T_800a5_row11_col0" class="data row11 col0" >Meat of pig with the bone, fresh or chilled (biological)</td>
#       <td id="T_800a5_row11_col1" class="data row11 col1" >5,619</td>
#     </tr>
#     <tr>
#       <td id="T_800a5_row12_col0" class="data row12 col0" >Cocoa beans</td>
#       <td id="T_800a5_row12_col1" class="data row12 col1" >5,019</td>
#     </tr>
#     <tr>
#       <td id="T_800a5_row13_col0" class="data row13 col0" >Ginger, raw</td>
#       <td id="T_800a5_row13_col1" class="data row13 col1" >4,589</td>
#     </tr>
#     <tr>
#       <td id="T_800a5_row14_col0" class="data row14 col0" >Chillies and peppers, green (Capsicum spp. and Pimenta spp.)</td>
#       <td id="T_800a5_row14_col1" class="data row14 col1" >4,458</td>
#     </tr>
#     <tr>
#       <td id="T_800a5_row15_col0" class="data row15 col0" >Hen eggs in shell, fresh</td>
#       <td id="T_800a5_row15_col1" class="data row15 col1" >4,078</td>
#     </tr>
#     <tr>
#       <td id="T_800a5_row16_col0" class="data row16 col0" >Meat of ducks, fresh or chilled (biological)</td>
#       <td id="T_800a5_row16_col1" class="data row16 col1" >3,887</td>
#     </tr>
#     <tr>
#       <td id="T_800a5_row17_col0" class="data row17 col0" >Meat of chickens, fresh or chilled (biological)</td>
#       <td id="T_800a5_row17_col1" class="data row17 col1" >3,764</td>
#     </tr>
#     <tr>
#       <td id="T_800a5_row18_col0" class="data row18 col0" >Natural rubber in primary forms</td>
#       <td id="T_800a5_row18_col1" class="data row18 col1" >3,755</td>
#     </tr>
#     <tr>
#       <td id="T_800a5_row19_col0" class="data row19 col0" >Meat of ducks, fresh or chilled</td>
#       <td id="T_800a5_row19_col1" class="data row19 col1" >3,529</td>
#     </tr>
#     <tr>
#       <td id="T_800a5_row20_col0" class="data row20 col0" >Meat of chickens, fresh or chilled</td>
#       <td id="T_800a5_row20_col1" class="data row20 col1" >3,206</td>
#     </tr>
#     <tr>
#       <td id="T_800a5_row21_col0" class="data row21 col0" >Leeks and other alliaceous vegetables</td>
#       <td id="T_800a5_row21_col1" class="data row21 col1" >2,918</td>
#     </tr>
#     <tr>
#       <td id="T_800a5_row22_col0" class="data row22 col0" >Mangoes, guavas and mangosteens</td>
#       <td id="T_800a5_row22_col1" class="data row22 col1" >2,612</td>
#     </tr>
#     <tr>
#       <td id="T_800a5_row23_col0" class="data row23 col0" >Okra</td>
#       <td id="T_800a5_row23_col1" class="data row23 col1" >2,589</td>
#     </tr>
#     <tr>
#       <td id="T_800a5_row24_col0" class="data row24 col0" >Meat of pig with the bone, fresh or chilled</td>
#       <td id="T_800a5_row24_col1" class="data row24 col1" >2,505</td>
#     </tr>
#     <tr>
#       <td id="T_800a5_row25_col0" class="data row25 col0" >Cauliflowers and broccoli</td>
#       <td id="T_800a5_row25_col1" class="data row25 col1" >2,471</td>
#     </tr>
#     <tr>
#       <td id="T_800a5_row26_col0" class="data row26 col0" >Lettuce and chicory</td>
#       <td id="T_800a5_row26_col1" class="data row26 col1" >2,334</td>
#     </tr>
#     <tr>
#       <td id="T_800a5_row27_col0" class="data row27 col0" >Yams</td>
#       <td id="T_800a5_row27_col1" class="data row27 col1" >2,265</td>
#     </tr>
#     <tr>
#       <td id="T_800a5_row28_col0" class="data row28 col0" >Lemons and limes</td>
#       <td id="T_800a5_row28_col1" class="data row28 col1" >2,259</td>
#     </tr>
#     <tr>
#       <td id="T_800a5_row29_col0" class="data row29 col0" >Green corn (maize)</td>
#       <td id="T_800a5_row29_col1" class="data row29 col1" >2,189</td>
#     </tr>
#     <tr>
#       <td id="T_800a5_row30_col0" class="data row30 col0" >Eggplants (aubergines)</td>
#       <td id="T_800a5_row30_col1" class="data row30 col1" >2,084</td>
#     </tr>
#     <tr>
#       <td id="T_800a5_row31_col0" class="data row31 col0" >Bananas ca

# %%
styled_highlight = avg_prices.style \
    .format({"Avg Producer Price Index": "{:,.0f}"}) \
    .background_gradient(subset="Avg Producer Price Index", cmap="YlOrRd") \
    .set_caption("Average Producer Price Index by Commodity (Highlight by Price)") \
    .hide(axis='index')

display(styled_highlight)
# Out:
# <style type="text/css">
# #T_436c4_row0_col1 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_436c4_row1_col1 {
#   background-color: #8b0026;
#   color: #f1f1f1;
# }
# #T_436c4_row2_col1 {
#   background-color: #b90026;
#   color: #f1f1f1;
# }
# #T_436c4_row3_col1 {
#   background-color: #bb0026;
#   color: #f1f1f1;
# }
# #T_436c4_row4_col1 {
#   background-color: #dc151e;
#   color: #f1f1f1;
# }
# #T_436c4_row5_col1 {
#   background-color: #f03523;
#   color: #f1f1f1;
# }
# #T_436c4_row6_col1 {
#   background-color: #fa4a29;
#   color: #f1f1f1;
# }
# #T_436c4_row7_col1 {
#   background-color: #fc592d;
#   color: #f1f1f1;
# }
# #T_436c4_row8_col1 {
#   background-color: #fc5f2f;
#   color: #f1f1f1;
# }
# #T_436c4_row9_col1 {
#   background-color: #fd9640;
#   color: #000000;
# }
# #T_436c4_row10_col1 {
#   background-color: #fd9740;
#   color: #000000;
# }
# #T_436c4_row11_col1 {
#   background-color: #fea747;
#   color: #000000;
# }
# #T_436c4_row12_col1 {
#   background-color: #feb44e;
#   color: #000000;
# }
# #T_436c4_row13_col1 {
#   background-color: #febe59;
#   color: #000000;
# }
# #T_436c4_row14_col1 {
#   background-color: #fec15d;
#   color: #000000;
# }
# #T_436c4_row15_col1 {
#   background-color: #feca66;
#   color: #000000;
# }
# #T_436c4_row16_col1 {
#   background-color: #fecf6b;
#   color: #000000;
# }
# #T_436c4_row17_col1, #T_436c4_row18_col1 {
#   background-color: #fed16e;
#   color: #000000;
# }
# #T_436c4_row19_col1 {
#   background-color: #fed774;
#   color: #000000;
# }
# #T_436c4_row20_col1 {
#   background-color: #fedc7c;
#   color: #000000;
# }
# #T_436c4_row21_col1 {
#   background-color: #fedf83;
#   color: #000000;
# }
# #T_436c4_row22_col1 {
#   background-color: #fee38b;
#   color: #000000;
# }
# #T_436c4_row23_col1 {
#   background-color: #ffe48c;
#   color: #000000;
# }
# #T_436c4_row24_col1 {
#   background-color: #ffe48d;
#   color: #000000;
# }
# #T_436c4_row25_col1 {
#   background-color: #ffe58f;
#   color: #000000;
# }
# #T_436c4_row26_col1 {
#   background-color: #ffe691;
#   color: #000000;
# }
# #T_436c4_row27_col1, #T_436c4_row28_col1 {
#   background-color: #ffe794;
#   color: #000000;
# }
# #T_436c4_row29_col1 {
#   background-color: #ffe895;
#   color: #000000;
# }
# #T_436c4_row30_col1 {
#   background-color: #ffe998;
#   color: #000000;
# }
# #T_436c4_row31_col1 {
#   background-color: #ffea9b;
#   color: #000000;
# }
# #T_436c4_row32_col1 {
#   background-color: #ffec9d;
#   color: #000000;
# }
# #T_436c4_row33_col1, #T_436c4_row34_col1, #T_436c4_row35_col1 {
#   background-color: #ffeda0;
#   color: #000000;
# }
# #T_436c4_row36_col1 {
#   background-color: #ffeea3;
#   color: #000000;
# }
# #T_436c4_row37_col1 {
#   background-color: #fff0a7;
#   color: #000000;
# }
# #T_436c4_row38_col1, #T_436c4_row39_col1 {
#   background-color: #fff1a9;
#   color: #000000;
# }
# #T_436c4_row40_col1 {
#   background-color: #fff1ab;
#   color: #000000;
# }
# #T_436c4_row41_col1 {
#   background-color: #fff3ae;
#   color: #000000;
# }
# #T_436c4_row42_col1, #T_436c4_row43_col1 {
#   background-color: #fff3af;
#   color: #000000;
# }
# #T_436c4_row44_col1 {
#   background-color: #fff4b0;
#   color: #000000;
# }
# #T_436c4_row45_col1, #T_436c4_row46_col1 {
#   background-color: #fff5b3;
#   color: #000000;
# }
# #T_436c4_row47_col1, #T_436c4_row48_col1, #T_436c4_row49_col1 {
#   background-color: #fff5b5;
#   color: #000000;
# }
# #T_436c4_row50_col1 {
#   background-color: #fff7b7;
#   color: #000000;
# }
# #T_436c4_row51_col1 {
#   background-color: #fff7b9;
#   color: #000000;
# }
# #T_436c4_row52_col1 {
#   background-color: #fff8ba;
#   color: #000000;
# }
# #T_436c4_row53_col1 {
#   background-color: #fff8bb;
#   color: #000000;
# }
# #T_436c4_row54_col1, #T_436c4_row55_col1 {
#   background-color: #fff9bd;
#   color: #000000;
# }
# #T_436c4_row56_col1 {
#   background-color: #fff9be;
#   color: #000000;
# }
# #T_436c4_row57_col1 {
#   background-color: #fffbc2;
#   color: #000000;
# }
# #T_436c4_row58_col1, #T_436c4_row59_col1 {
#   background-color: #fffcc4;
#   color: #000000;
# }
# #T_436c4_row60_col1, #T_436c4_row61_col1, #T_436c4_row62_col1, #T_436c4_row63_col1, #T_436c4_row64_col1, #T_436c4_row65_col1, #T_436c4_row66_col1, #T_436c4_row67_col1, #T_436c4_row68_col1, #T_436c4_row69_col1, #T_436c4_row70_col1, #T_436c4_row71_col1, #T_436c4_row72_col1, #T_436c4_row73_col1, #T_436c4_row74_col1, #T_436c4_row75_col1, #T_436c4_row76_col1, #T_436c4_row77_col1, #T_436c4_row78_col1, #T_436c4_row79_col1, #T_436c4_row80_col1, #T_436c4_row81_col1, #T_436c4_row82_col1, #T_436c4_row83_col1, #T_436c4_row84_col1, #T_436c4_row85_col1, #T_436c4_row86_col1, #T_436c4_row87_col1 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# </style>
# <table id="T_436c4">
#   <caption>Average Producer Price Index by Commodity (Highlight by Price)</caption>
#   <thead>
#     <tr>
#       <th id="T_436c4_level0_col0" class="col_heading level0 col0" >Commodity</th>
#       <th id="T_436c4_level0_col1" class="col_heading level0 col1" >Avg Producer Price Index</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_436c4_row0_col0" class="data row0 col0" >Meat of goat, fresh or chilled (biological)</td>
#       <td id="T_436c4_row0_col1" class="data row0 col1" >13,523</td>
#     </tr>
#     <tr>
#       <td id="T_436c4_row1_col0" class="data row1 col0" >Meat of sheep, fresh or chilled (biological)</td>
#       <td id="T_436c4_row1_col1" class="data row1 col1" >13,202</td>
#     </tr>
#     <tr>
#       <td id="T_436c4_row2_col0" class="data row2 col0" >Meat of goat, fresh or chilled</td>
#       <td id="T_436c4_row2_col1" class="data row2 col1" >11,899</td>
#     </tr>
#     <tr>
#       <td id="T_436c4_row3_col0" class="data row3 col0" >Pepper (Piper spp.), raw</td>
#       <td id="T_436c4_row3_col1" class="data row3 col1" >11,861</td>
#     </tr>
#     <tr>
#       <td id="T_436c4_row4_col0" class="data row4 col0" >Asparagus</td>
#       <td id="T_436c4_row4_col1" class="data row4 col1" >10,452</td>
#     </tr>
#     <tr>
#       <td id="T_436c4_row5_col0" class="data row5 col0" >Meat of cattle with the bone, fresh or chilled</td>
#       <td id="T_436c4_row5_col1" class="data row5 col1" >9,271</td>
#     </tr>
#     <tr>
#       <td id="T_436c4_row6_col0" class="data row6 col0" >Unmanufactured tobacco</td>
#       <td id="T_436c4_row6_col1" class="data row6 col1" >8,630</td>
#     </tr>
#     <tr>
#       <td id="T_436c4_row7_col0" class="data row7 col0" >Meat of buffalo, fresh or chilled (biological)</td>
#       <td id="T_436c4_row7_col1" class="data row7 col1" >8,206</td>
#     </tr>
#     <tr>
#       <td id="T_436c4_row8_col0" class="data row8 col0" >Meat of cattle with the bone, fresh or chilled (biological)</td>
#       <td id="T_436c4_row8_col1" class="data row8 col1" >8,021</td>
#     </tr>
#     <tr>
#       <td id="T_436c4_row9_col0" class="data row9 col0" >Meat of sheep, fresh or chilled</td>
#       <td id="T_436c4_row9_col1" class="data row9 col1" >6,419</td>
#     </tr>
#     <tr>
#       <td id="T_436c4_row10_col0" class="data row10 col0" >Meat of buffalo, fresh or chilled</td>
#       <td id="T_436c4_row10_col1" class="data row10 col1" >6,370</td>
#     </tr>
#     <tr>
#       <td id="T_436c4_row11_col0" class="data row11 col0" >Meat of pig with the bone, fresh or chilled (biological)</td>
#       <td id="T_436c4_row11_col1" class="data row11 col1" >5,619</td>
#     </tr>
#     <tr>
#       <td id="T_436c4_row12_col0" class="data row12 col0" >Cocoa beans</td>
#       <td id="T_436c4_row12_col1" class="data row12 col1" >5,019</td>
#     </tr>
#     <tr>
#       <td id="T_436c4_row13_col0" class="data row13 col0" >Ginger, raw</td>
#       <td id="T_436c4_row13_col1" class="data row13 col1" >4,589</td>
#     </tr>
#     <tr>
#       <td id="T_436c4_row14_col0" class="data row14 col0" >Chillies and peppers, green (Capsicum spp. and Pimenta spp.)</td>
#       <td id="T_436c4_row14_col1" class="data row14 col1" >4,458</td>
#     </tr>
#     <tr>
#       <td id="T_436c4_row15_col0" class="data row15 col0" >Hen eggs in shell, fresh</td>
#       <td id="T_436c4_row15_col1" class="data row15 col1" >4,078</td>
#     </tr>
#     <tr>
#       <td id="T_436c4_row16_col0" class="data row16 col0" >Meat of ducks, fresh or chilled (biological)</td>
#       <td id="T_436c4_row16_col1" class="data row16 col1" >3,887</td>
#     </tr>
#     <tr>
#       <td id="T_436c4_row17_col0" class="data row17 col0" >Meat of chickens, fresh or chilled (biological)</

# %%
# Concatenate top 10 and bottom 10
top_bottom = pd.concat([
    avg_prices.head(10),
    avg_prices.tail(10)
]).reset_index(drop=True)

display(
    top_bottom.style.format({"Avg Producer Price Index": "{:,.0f}"})
    .set_caption("Top and Bottom 10 Commodities by Producer Price Index")
    .hide(axis='index')
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_2a16b">
#   <caption>Top and Bottom 10 Commodities by Producer Price Index</caption>
#   <thead>
#     <tr>
#       <th id="T_2a16b_level0_col0" class="col_heading level0 col0" >Commodity</th>
#       <th id="T_2a16b_level0_col1" class="col_heading level0 col1" >Avg Producer Price Index</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2a16b_row0_col0" class="data row0 col0" >Areca nuts</td>
#       <td id="T_2a16b_row0_col1" class="data row0 col1" >81</td>
#     </tr>
#     <tr>
#       <td id="T_2a16b_row1_col0" class="data row1 col0" >Bananas</td>
#       <td id="T_2a16b_row1_col1" class="data row1 col1" >1,154</td>
#     </tr>
#     <tr>
#       <td id="T_2a16b_row2_col0" class="data row2 col0" >Bananas cavendish</td>
#       <td id="T_2a16b_row2_col1" class="data row2 col1" >1,983</td>
#     </tr>
#     <tr>
#       <td id="T_2a16b_row3_col0" class="data row3 col0" >Cabbages</td>
#       <td id="T_2a16b_row3_col1" class="data row3 col1" >1,186</td>
#     </tr>
#     <tr>
#       <td id="T_2a16b_row4_col0" class="data row4 col0" >Carrots and turnips</td>
#       <td id="T_2a16b_row4_col1" class="data row4 col1" >1,388</td>
#     </tr>
#     <tr>
#       <td id="T_2a16b_row5_col0" class="data row5 col0" >Cashew nuts, in shell</td>
#       <td id="T_2a16b_row5_col1" class="data row5 col1" >80</td>
#     </tr>
#     <tr>
#       <td id="T_2a16b_row6_col0" class="data row6 col0" >Cassava, fresh</td>
#       <td id="T_2a16b_row6_col1" class="data row6 col1" >767</td>
#     </tr>
#     <tr>
#       <td id="T_2a16b_row7_col0" class="data row7 col0" >Cauliflowers and broccoli</td>
#       <td id="T_2a16b_row7_col1" class="data row7 col1" >2,471</td>
#     </tr>
#     <tr>
#       <td id="T_2a16b_row8_col0" class="data row8 col0" >Chillies and peppers, dry (Capsicum spp., Pimenta spp.), raw</td>
#       <td id="T_2a16b_row8_col1" class="data row8 col1" >79</td>
#     </tr>
#     <tr>
#       <td id="T_2a16b_row9_col0" class="data row9 col0" >Chillies and peppers, green (Capsicum spp. and Pimenta spp.)</td>
#       <td id="T_2a16b_row9_col1" class="data row9 col1" >4,458</td>
#     </tr>
#     <tr>
#       <td id="T_2a16b_row10_col0" class="data row10 col0" >Sugar cane</td>
#       <td id="T_2a16b_row10_col1" class="data row10 col1" >600</td>
#     </tr>
#     <tr>
#       <td id="T_2a16b_row11_col0" class="data row11 col0" >Sweet potatoes</td>
#       <td id="T_2a16b_row11_col1" class="data row11 col1" >1,194</td>
#     </tr>
#     <tr>
#       <td id="T_2a16b_row12_col0" class="data row12 col0" >Tangerines, mandarins, clementines</td>
#       <td id="T_2a16b_row12_col1" class="data row12 col1" >708</td>
#     </tr>
#     <tr>
#       <td id="T_2a16b_row13_col0" class="data row13 col0" >Tea leaves</td>
#       <td id="T_2a16b_row13_col1" class="data row13 col1" >79</td>
#     </tr>
#     <tr>
#       <td id="T_2a16b_row14_col0" class="data row14 col0" >Tomatoes</td>
#       <td id="T_2a16b_row14_col1" class="data row14 col1" >1,785</td>
#     </tr>
#     <tr>
#       <td id="T_2a16b_row15_col0" class="data row15 col0" >Treenuts, Total</td>
#       <td id="T_2a16b_row15_col1" class="data row15 col1" >80</td>
#     </tr>
#     <tr>
#       <td id="T_2a16b_row16_col0" class="data row16 col0" >Vegetables Primary</td>
#       <td id="T_2a16b_row16_col1" class="data row16 col1" >82</td>
#     </tr>
#     <tr>
#       <td id="T_2a16b_row17_col0" class="data row17 col0" >Vegetables&Melons, Total</td>
#       <td id="T_2a16b_row17_col1" class="data row17 col1" >82</td>
#     </tr>
#     <tr>
#       <td id="T_2a16b_row18_col0" class="data row18 col0" >Watermelons</td>
#       <td id="T_2a16b_row18_col1" class="data row18 col1" >893</td>
#     </tr>
#     <tr>
#       <td id="T_2a16b_row19_col0" class="data row19 col0" >Yams</td>
#       <td id="T_2a16b_row19_col1" class="data row19 col1" >2,265</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Average and style the table
avg_prices = plant_foods.groupby("Commodity")["Value"].mean().reset_index()
avg_prices.columns = ["Commodity", "Avg Producer Price Index"]
avg_prices["Avg Producer Price Index"] = avg_prices["Avg Producer Price Index"].round(0).astype(int)

# Highlighted style with ascending yellow to red color scale
styled_highlight = avg_prices.style \
    .format({"Avg Producer Price Index": "{:,.0f}"}) \
    .background_gradient(subset="Avg Producer Price Index", cmap="YlOrRd") \
    .set_caption("Average Producer Price Index for Plant-Based Whole Foods (2014–2016 = 100)") \
    .hide(axis='index')

display(styled_highlight)
# Out:
# <style type="text/css">
# #T_e1d6f_row0_col1, #T_e1d6f_row5_col1, #T_e1d6f_row8_col1, #T_e1d6f_row10_col1, #T_e1d6f_row13_col1, #T_e1d6f_row15_col1, #T_e1d6f_row17_col1, #T_e1d6f_row20_col1, #T_e1d6f_row26_col1, #T_e1d6f_row30_col1, #T_e1d6f_row38_col1, #T_e1d6f_row39_col1, #T_e1d6f_row44_col1, #T_e1d6f_row46_col1, #T_e1d6f_row47_col1, #T_e1d6f_row48_col1 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_e1d6f_row1_col1 {
#   background-color: #fff2ac;
#   color: #000000;
# }
# #T_e1d6f_row2_col1 {
#   background-color: #ffe794;
#   color: #000000;
# }
# #T_e1d6f_row3_col1, #T_e1d6f_row42_col1 {
#   background-color: #fff1ab;
#   color: #000000;
# }
# #T_e1d6f_row4_col1, #T_e1d6f_row40_col1 {
#   background-color: #ffefa5;
#   color: #000000;
# }
# #T_e1d6f_row6_col1 {
#   background-color: #fff7b7;
#   color: #000000;
# }
# #T_e1d6f_row7_col1 {
#   background-color: #fee085;
#   color: #000000;
# }
# #T_e1d6f_row9_col1 {
#   background-color: #feb34d;
#   color: #000000;
# }
# #T_e1d6f_row11_col1 {
#   background-color: #fea546;
#   color: #000000;
# }
# #T_e1d6f_row12_col1, #T_e1d6f_row43_col1 {
#   background-color: #fff8ba;
#   color: #000000;
# }
# #T_e1d6f_row14_col1, #T_e1d6f_row32_col1 {
#   background-color: #fff4b2;
#   color: #000000;
# }
# #T_e1d6f_row16_col1 {
#   background-color: #ffe691;
#   color: #000000;
# }
# #T_e1d6f_row18_col1 {
#   background-color: #feaf4b;
#   color: #000000;
# }
# #T_e1d6f_row19_col1 {
#   background-color: #ffe48d;
#   color: #000000;
# }
# #T_e1d6f_row21_col1 {
#   background-color: #fedb7a;
#   color: #000000;
# }
# #T_e1d6f_row22_col1, #T_e1d6f_row50_col1 {
#   background-color: #ffe48c;
#   color: #000000;
# }
# #T_e1d6f_row23_col1 {
#   background-color: #fee289;
#   color: #000000;
# }
# #T_e1d6f_row24_col1 {
#   background-color: #fffcc4;
#   color: #000000;
# }
# #T_e1d6f_row25_col1 {
#   background-color: #fede82;
#   color: #000000;
# }
# #T_e1d6f_row27_col1 {
#   background-color: #fedf83;
#   color: #000000;
# }
# #T_e1d6f_row28_col1 {
#   background-color: #fff1a9;
#   color: #000000;
# }
# #T_e1d6f_row29_col1 {
#   background-color: #ffea9b;
#   color: #000000;
# }
# #T_e1d6f_row31_col1 {
#   background-color: #ffe998;
#   color: #000000;
# }
# #T_e1d6f_row33_col1 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_e1d6f_row34_col1, #T_e1d6f_row36_col1 {
#   background-color: #fff4b0;
#   color: #000000;
# }
# #T_e1d6f_row35_col1, #T_e1d6f_row45_col1 {
#   background-color: #ffea99;
#   color: #000000;
# }
# #T_e1d6f_row37_col1 {
#   background-color: #fff6b6;
#   color: #000000;
# }
# #T_e1d6f_row41_col1 {
#   background-color: #fff9bd;
#   color: #000000;
# }
# #T_e1d6f_row49_col1 {
#   background-color: #fff5b5;
#   color: #000000;
# }
# </style>
# <table id="T_e1d6f">
#   <caption>Average Producer Price Index for Plant-Based Whole Foods (2014–2016 = 100)</caption>
#   <thead>
#     <tr>
#       <th id="T_e1d6f_level0_col0" class="col_heading level0 col0" >Commodity</th>
#       <th id="T_e1d6f_level0_col1" class="col_heading level0 col1" >Avg Producer Price Index</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e1d6f_row0_col0" class="data row0 col0" >Areca nuts</td>
#       <td id="T_e1d6f_row0_col1" class="data row0 col1" >81</td>
#     </tr>
#     <tr>
#       <td id="T_e1d6f_row1_col0" class="data row1 col0" >Bananas</td>
#       <td id="T_e1d6f_row1_col1" class="data row1 col1" >1,154</td>
#     </tr>
#     <tr>
#       <td id="T_e1d6f_row2_col0" class="data row2 col0" >Bananas cavendish</td>
#       <td id="T_e1d6f_row2_col1" class="data row2 col1" >1,983</td>
#     </tr>
#     <tr>
#       <td id="T_e1d6f_row3_col0" class="data row3 col0" >Cabbages</td>
#       <td id="T_e1d6f_row3_col1" class="data row3 col1" >1,186</td>
#     </tr>
#     <tr>
#       <td id="T_e1d6f_row4_col0" class="data row4 col0" >Carrots and turnips</td>
#       <td id="T_e1d6f_row4_col1" class="data row4 col1" >1,388</td>
#     </tr>
#     <tr>
#       <td id="T_e1d6f_row5_col0" class="data row5 col0" >Cashew nuts, in shell</td>
#       <td id="T_e1d6f_row5_col1" class="data row5 col1" >80</td>
#     </tr>
#     <tr>
#       <td id="T_e1d6f_row6_col0" class="data row6 col0" >Cassava, fresh</td>
#       <td id="T_e1d6f_row6_col1" class="data row6 col1" >767</td>
#     </tr>
#     <tr>
#       <td id="T_e1d6f_row7_col0" class="data row7 col0" >Cauliflowers and broccoli</td>
#       <td id="T_e1d6f_row7_col1" class="data row7 col1" >2,471</td>
#     </tr>
#     <tr>
#       <td id="T_e1d6f_row8_col0" class="data row8 col0" >Chillies and peppers, dry (Capsicum spp., Pimenta spp.), raw</td>
#       <td id="T_e1d6f_row8_col1" class="data row8 col1" >79</td>
#     </tr>
#     <tr>
#       <td id="T_e1d6f_row9_col0" class="data row9 col0" >Chillies and peppers, green (Capsicum spp. and Pimenta spp.)</td>
#       <td id="T_e1d6f_row9_col1" class="data row9 col1" >4,458</td>
#     </tr>
#     <tr>
#       <td id="T_e1d6f_row10_col0" class="data row10 col0" >Cloves (whole stems), raw</td>
#       <td id="T_e1d6f_row10_col1" class="data row10 col1" >80</td>
#     </tr>
#     <tr>
#       <td id="T_e1d6f_row11_col0" class="data row11 col0" >Cocoa beans</td>
#       <td id="T_e1d6f_row11_col1" class="data row11 col1" >5,019</td>
#     </tr>
#     <tr>
#       <td id="T_e1d6f_row12_col0" class="data row12 col0" >Coconuts, in shell</td>
#       <td id="T_e1d6f_row12_col1" class="data row12 col1" >694</td>
#     </tr>
#     <tr>
#       <td id="T_e1d6f_row13_col0" class="data row13 col0" >Coffee, green</td>
#       <td id="T_e1d6f_row13_col1" class="data row13 col1" >81</td>
#     </tr>
#     <tr>
#       <td id="T_e1d6f_row14_col0" class="data row14 col0" >Cucumbers and gherkins</td>
#       <td id="T_e1d6f_row14_col1" class="data row14 col1" >986</td>
#     </tr>
#     <tr>
#       <td id="T_e1d6f_row15_col0" class="data row15 col0" >Edible roots and tubers with high starch or inulin content, n.e.c., fresh</td>
#       <td id="T_e1d6f_row15_col1" class="data row15 col1" >81</td>
#     </tr>
#     <tr>
#       <td id="T_e1d6f_row16_col0" class="data row16 col0" >Eggplants (aubergines)</td>
#       <td id="T_e1d6f_row16_col1" class="data row16 col1" >2,084</td>
#     </tr>
#     <tr>
#       <td id="T_e1d6f_row17_col0" class="data row17 col0" >Fruit excl Melons, Total</td>
#       <td id="T_e1d6f_row17_col1" class="data row17 col1" >72</td>
#     </tr>
#     <tr>
#       <td id="T_e1d6f_row18_col0" class="data row18 col0" >Ginger, raw</td>
#       <td id="T_e1d6f_row18_col1" class="data row18 col1" >4,589</td>
#     </tr>
#     <tr>
#       <td id="T_e1d6f_row19_col0" class="data row19 col0" >Green corn (maize)</td>
#       <td id="T_e1d6f_row19_col1" class="data row19 col1" >2,189</td>
#     </tr>
#     <tr>
#       <td id="T_e1d6f_row20_col0" class="data row20 col0" >Groundnuts, excluding shelled</td>
#       <td id="T_e1d6f_row20_col1" class="data row20 col1" >81</td>
#     </tr>
#     <tr>
#       <td id="T_e1d6f_row21_col0" class="data row21 col0" >Leeks and other alliaceous vegetables</td>
#       <td id="T_e1d6f_row21_col1" class="data row21 col1" >2,918</td>
#     </tr>
#     <tr>
#       <td id="T_e1d6f_row22_col0" class="data row22 col0" >Lemons and limes</td>
#       <td id="T_e1d6f_row22_col1" class="data row22 col1" >2,259</td>
#     </tr>
#     <tr>
#       <td id="T_e1d6f_row23_col0" class="data row23 col0" >Lettuce and chicory</td>
#       <td id="T_e1d6f_row23_col1" class="data row23 col1" >2,334</td>
#     </tr>
#     <tr>
#       <td id="T_e1d6f_row24_col0" class="data row24 col0" >Maize (corn)</td>
#       <td id="T_e1d6f_row24_col1" class="data row24 col1" >388</td>
#     </tr>
#     <tr>
#       <td id="T_e1d6f_row25_col0" class="data row25 col0" >Mangoes, guavas and mangosteens</td>
#       <td id="T_e1d6f_row25_col1" class="data row25 col1" >2,612</td>
#     </tr>
#     <tr>
#       <td id="T_e1d6f_row26_col0" class="data row26 col0" >Nutmeg, mace, cardamoms, raw</td>
#       <td id="T_e1d6f_row26_col1" class="data row26 col1" >80</td>
#     </tr>
#     <tr>
#       <td id="T_e1d6f_row27_col0" class="data row27 col0" >Okra</td>
#       <td id="T_e1d6f_row27_col1" class="data row27 col1" >2,589</td>
#     </tr>
#     <tr>
#       <td id="T_e1d6f_row28_col0" class="data row28 col0" >Oranges</td>
#       <td id="T_e1d6f_row28_col1" class="data row28 col1" >1,225</td>
#     </tr>
#     <tr>
#       <td id="T_e1d6f_row29_col0" class="data r

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv("producer-prices_mys.csv")

# Filter only Producer Price Index entries
df = df[df['Element'] == 'Producer Price Index (2014-2016 = 100)'].copy()

# Convert 'Value' to numeric and drop invalid entries
df['Value'] = pd.to_numeric(df['Value'], errors='coerce')
df = df.dropna(subset=['Value', 'Year'])

# -------------------------------
# Classify Items by Food Category
# -------------------------------

# Define detailed keywords
plant_keywords = [
    "vegetable", "legume", "fruit", "cruciferous", "greens", "beans",
    "nuts", "seeds", "herb", "spices", "whole grain", "maize", "cassava", "ginger",
    "lettuce", "mangoes", "cabbages", "carrots", "broccoli", "cucumbers",
    "cauliflowers", "bananas", "eggplants", "leeks", "coffee", "cocoa", "coconut",
    "pepper", "asparagus", "corn", "turnips", "chillies", "onion", "garlic"
]

animal_keywords = [
    "meat", "egg", "milk", "dairy", "livestock", "buffalo", "cattle", "chicken", "duck", "goat", "pig", "horse"
]

# Categorization function
def classify_item(item):
    item_lower = str(item).lower()
    if any(k in item_lower for k in plant_keywords):
        return "Plant-Based"
    elif any(k in item_lower for k in animal_keywords):
        return "Animal-Based"
    else:
        return "Other"

# Apply classification
df['Category'] = df['Item'].apply(classify_item)

# -------------------------------
# Aggregate by Year and Category
# -------------------------------
grouped = df[df['Category'].isin(["Plant-Based", "Animal-Based"])]
trend_data = grouped.groupby(['Year', 'Category'])['Value'].mean().unstack()

# -------------------------------
# Plotting
# -------------------------------
plt.figure(figsize=(12, 6))
trend_data.plot(marker='o')
plt.title("Time Series of Producer Price Index in Malaysia by Food Category")
plt.ylabel("Producer Price Index (2014–2016 = 100)")
plt.xlabel("Year")
plt.grid(True)
plt.legend(title="Food Category")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 5
#       2 import matplotlib.pyplot as plt
#       4 # Load the dataset
# ----> 5 df = pd.read_csv("producer-prices_mys.csv")
#       7 # Filter only Producer Price Index entries
#       8 df = df[df['Element'] == 'Producer Price Index (2014-2016 = 100)'].copy()
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File ~\anaconda3\Lib\site-packages\pandas\io\common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'producer-prices_mys.csv'
